# %%
### LIBRARIES / HEADER STUFF {
import json                  # Initial dataset import
from graphviz import Digraph # Primary renderer
### }

# %%
### Hyperparams {
REMOVEGRADCLASS = True
REQUIREMENTCOLOR = False
required = {'PHYS039','MATH009A','MATH009B','MATH009C','CHEM001A',
                'CHEM001B','CHEM001C','CS010','MATH010A','MATH010B','MATH046',
                'PHYS041A','PHYS041B','PHYS041C','PHYS130A','PHYS130B','PHYS132',
                'PHYS135A','PHYS135B','PHYS156A','PHYS156B','PHYS139L','PHYS142W'}
remove_nonmajor = True
DARKTHEME = True
DARKTHEMECOLORS = {'background':'#043742',
                   'boxes':'#6a8690',
                   'lines':'#3fc6b4',
                   'textcolor':'white'}
### }

# %%
### IMPORT FROM DATASET {

# Opens and autocloses the file, binds file to f, and loads the data
with open('/home/order/Dropbox/Python_Code/Cloned/ucr-course-graph/data/201740_all_prereqs.json','r') as f:
    data = json.load(f)

# Define course object
class course:
    def __init__(self, courseName, preReq, courseID, subject):
        self.courseName = courseName
        self.preReq = preReq
        self.courseID = courseID
        self.subject = subject

# Mildly brittle parser
def parseAndOr(testString):
    # Presumption: AND statements are top level, then there are OR statements.
    # So there's nothing like (CS 111 AND CS 11) OR (MATH 031 AND MATH 10A)
    # This is important because the parser 
    if testString == dict():
        return dict()
    if len(testString.split('\n')) < 3:
        return dict()
    if 'Score for' in testString: # EXTREMELY HACKY SOLUTION
        return dict()
    mod = testString.split('and\n')
    mod = [x.split('or\n') for x in mod]
    mod = [[y.split('\n') for y in x] for x in mod]
    
    # Now get all of the 'Computer Science': 'CS' type information
    with open('/home/order/Dropbox/Python_Code/Cloned/ucr-course-graph/data/subjects.json') as f:
        codes = json.load(f)
    lookup = {x['description']:x['code'] for x in codes}
    
    def classconvert(classname):
        intermed = classname.split(' ')
        intermed = [' '.join(intermed[:-1]), intermed[-1]]
        # lookup is defined above
        if intermed[0] in lookup:
            return lookup[intermed[0]] + intermed[1]
        else:
            return classname
    
    try:
        # This is the most horrific list comprehension I've every written, but it works
        mod = [[[
             classconvert(y[1][y[1].index('Test:')+6:].strip()), # Class name
             y[2].split(' ')[-1], # Grade
             'NC' if y[3].strip()[:7] == 'May not' else 'C' # Concurrent allowed?
                ] if y[0] == '(' else [
             classconvert(y[0][y[0].index('Test:')+6:].strip()), # Class name
             y[1].split(' ')[-1], # Grade
             'NC' if y[2].strip()[:7] == 'May not' else 'C' # Concurrent allowed?
                ] for y in x] for x in mod]
    except:
        print(testString)
        print(mod)
        raise
    return mod

courseList = []
for currentCourse in data:
    try: # Dealing with situations where prereq didn't get written
        mycourse = course(currentCourse['subjectCourse'], parseAndOr(currentCourse['prereqs']), currentCourse['id'], currentCourse['subject'])
    except KeyError:
        mycourse = course(currentCourse['subjectCourse'], dict(), currentCourse['id'], currentCourse['subject'])
    courseList.append(mycourse) # Writes course objects to a list

for i in courseList:
    if i.preReq != dict():
        print(i.preReq)

### }
# Out:
# [[['ANTH001', 'D-', 'NC'], ['ANTH001H', 'D-', 'NC'], ['ANTH001W', 'D-', 'NC']]]
# [[['ANTH003', 'D-', 'NC'], ['ANTH005', 'D-', 'NC']]]
# [[['ANTH003', 'D-', 'NC'], ['ANTH005', 'D-', 'NC']]]
# [[['ANTH001', 'D-', 'NC'], ['ANTH001H', 'D-', 'NC'], ['ANTH001W', 'D-', 'NC']], [['LING020', 'D-', 'NC']]]
# [[['ANTH001', 'D-', 'NC'], ['ANTH001H', 'D-', 'NC'], ['ANTH001W', 'D-', 'NC']]]
# [[['LING020', 'D-', 'NC']]]
# [[['ANTH001', 'D-', 'NC'], ['ANTH001H', 'D-', 'NC'], ['ANTH001W', 'D-', 'NC']]]
# [[['ANTH002', 'D-', 'NC']]]
# [[['ANTH002', 'D-', 'NC']]]
# [[['ANTH001', 'D-', 'NC'], ['ANTH001H', 'D-', 'NC'], ['ANTH001W', 'D-', 'NC']]]
# [[['ARBC003', 'C-', 'NC']]]
# [[['ART001', 'D-', 'NC']], [['ART002', 'D-', 'NC']]]
# [[['ART001', 'D-', 'NC']], [['ART002', 'D-', 'NC']]]
# [[['ART003', 'D-', 'NC']]]
# [[['CHEM008A', 'C-', 'C']], [['CHEM08LA', 'C-', 'C'], ['CHEM08HA', 'C-', 'C']], [['CHEM08HLA', 'C-', 'C'], ['CHEM12A', 'C-', 'NC'], ['CHEM12HA', 'C-', 'NC']]]
# [[['BIOL005A', 'C-', 'NC']], [['CHEM008C', 'C-', 'C']], [['CHEM08LC', 'C-', 'C'], ['CHEM08HC', 'C-', 'C']], [['CHEM08HLC', 'C-', 'C'], ['CHEM12C', 'C-', 'C'], ['CHEM12HC', 'C-', 'C']]]
# [[['PSYC001', 'C-', 'NC']]]
# [[['CBNS120', 'D-', 'C'], ['PSYC120', 'D-', 'C']]]
# [[['CBNS106', 'D-', 'NC']]]
# [[['CBNS106', 'C-', 'NC']]]
# [[['PSYC001', 'C-', 'NC']], [['PSYC002', 'C-', 'NC']], [['PSYC011', 'C-', 'NC']], [['PSYC012', 'C-', 'NC']]]
# [[['PSYC002', 'D-', 'NC']]]
# [[['PSYC001', 'C-', 'NC']], [['PSYC002', 'C-', 'NC']], [['PSYC011', 'C-', 'NC']], [['PSYC012', 'C-', 'NC']]]
# [[['PSYC001', 'C-', 'NC']], [['PSYC002', 'C-', 'NC']], [['PSYC011', 'C-', 'NC']], [['PSYC012', 'C-', 'NC']]]
# [[['PSYC001', 'C-', 'NC']], [['PSYC002', 'C-', 'NC']], [['PSYC011', 'C-', 'NC']], [['PSYC012', 'C-', 'NC']]]
# [[['PSYC001', 'C-', 'NC']], [['PSYC002', 'C-', 'NC']], [['PSYC011', 'C-', 'NC']], [['PSYC012', 'C-', 'NC']], [['PSYC160', 'D-', 'NC']]]
# [[['PSYC001', 'C-', 'NC']], [['PSYC002', 'C-', 'NC'], ['Law & Society 100', 'C-', 'NC']]]
# [[['PSYC001', 'C-', 'NC']], [['PSYC002', 'C-', 'NC']], [['PSYC011', 'C-', 'NC']], [['PSYC012', 'C-', 'NC']], [['PSYC134', 'C-', 'NC']]]
# [[['ECON003', 'D-', 'NC']]]
# [[['RUSN003', 'C-', 'NC']]]
# [[['SOC001', 'D-', 'NC'], ['SOC001H', 'D-', 'NC']]]
# [[['ENGL001B', 'C', 'NC']]]
# [[['POSC010', 'D-', 'NC'], ['POSC010H', 'D-', 'NC'], ['POSC010W', 'D-', 'NC']]]
# [[['POSC020', 'D-', 'NC']]]
# [[['POSC020', 'D-', 'NC'], ['POSC020H', 'D-', 'NC']]]
# [[['POSC010', 'D-', 'NC'], ['POSC010H', 'D-', 'NC'], ['POSC010W', 'D-', 'NC']]]
# [[['POSC201', 'D-', 'NC']]]
# [[['ENGL001B', 'C', 'NC']], [['PSYC001', 'C-', 'NC']], [['PSYC002', 'C-', 'NC']], [['PSYC011', 'C-', 'NC']]]
# [[['ENGL001A', 'C-', 'NC']]]
# [[['MATH007A', 'D-', 'NC'], ['MATH008B', 'D-', 'NC'], ['MATH009A', 'D-', 'NC'], ['MATH09HA', 'D-', 'NC']], [['CS010', 'D-', 'NC'], ['CS010V', 'D-', 'NC'], ['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']]]
# [[['CS010', 'C', 'NC'], ['CS010V', 'C', 'NC']]]
# [[['CS012', 'C', 'NC'], ['CS012V', 'C', 'NC']]]
# [[['CS010', 'C', 'NC'], ['CS010V', 'C', 'NC']]]
# [[['CS014', 'C-', 'NC']]]
# [[['CS010', 'D-', 'NC']], [['CS011', 'D-', 'NC'], ['MATH011', 'D-', 'NC']], [['MATH009C', 'D-', 'NC'], ['MATH09HC', 'D-', 'NC']]]
# [[['CS061', 'C-', 'NC']]]
# [[['CS012', 'D-', 'NC'], ['CS013', 'D-', 'NC']], [['CS120B', 'D-', 'NC'], ['EE120B', 'D-', 'NC']]]
# [[['CS100', 'D-', 'NC']], [['MATH031', 'D-', 'C']]]
# [[['CS014', 'C-', 'NC']], [['CS111', 'D-', 'NC']], [['MATH009C', 'D-', 'NC'], ['MATH09HC', 'D-', 'NC']]]
# [[['CS061', 'D-', 'NC']], [['CS100', 'D-', 'NC']], [['CS111', 'D-', 'NC']]]
# [[['EE120A', 'D-', 'NC'], ['CS120A', 'D-', 'NC']]]
# [[['EE120A', 'D-', 'NC'], ['CS120A', 'D-', 'NC']], [['CS161', 'D-', 'C']]]
# [[['CS100', 'D-', 'NC']], [['CS111', 'D-', 'NC']], [['CS153', 'D-', 'NC']]]
# [[['CS141', 'D-', 'NC']], [['CS153', 'D-', 'NC']]]
# [[['CS100', 'D-', 'NC']], [['CS111', 'D-', 'NC']]]
# [[['CS100', 'C-', 'NC']], [['CS111', 'D-', 'NC']]]
# [[['CS100', 'D-', 'NC']], [['MATH010A', 'D-', 'NC'], ['MATH031', 'D-', 'NC']]]
# [[['CS100', 'D-', 'NC']]]
# [[['CS153', 'D-', 'NC']]]
# [[['CS161', 'D-', 'NC']]]
# [[['CS141', 'D-', 'NC']], [['CS166', 'D-', 'NC']]]
# [[['DNCE014', 'D-', 'NC']]]
# [[['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']]]
# [[['GEO001', 'D-', 'C']], [['MATH004', 'D-', 'NC'], ['MATH005', 'D-', 'NC'], ['MATH008A', 'D-', 'NC']]]
# [[['CHEM001B', 'D-', 'C'], ['CHEM01HB', 'D-', 'C']], [['CHEM01LB', 'D-', 'C'], ['CHEM1HLB', 'D-', 'C']], [['GEO001', 'C-', 'NC']]]
# [[['GEO001', 'C-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC'], ['PHYS040C', 'D-', 'NC']]]
# [[['BIOL005C', 'D-', 'NC'], ['BIOL010', 'C-', 'NC'], ['GEO003', 'C-', 'NC']]]
# [[['GER002', 'C-', 'NC']]]
# [[['GRK003', 'C-', 'NC']]]
# [[['ETST001', 'D-', 'NC'], ['ETST001H', 'D-', 'NC']]]
# [[['ETST007', 'D-', 'NC'], ['ETST007H', 'D-', 'NC']]]
# [[['ETST001', 'D-', 'NC'], ['GSST010', 'D-', 'NC']]]
# [[['BIOL105', 'D-', 'NC']]]
# [[['FIL003', 'C-', 'NC']]]
# [[['FREN001', 'C-', 'NC']]]
# [[['FREN002', 'C-', 'NC']]]
# [[['FREN003', 'C-', 'NC']]]
# [[['FREN004', 'C', 'NC']]]
# [[['FREN015B', 'C', 'NC']]]
# [[['FREN101A', 'C', 'NC']]]
# [[['ECON003', 'D-', 'NC']]]
# [[['ETST001', 'D-', 'NC'], ['GSST010', 'D-', 'NC']]]
# [[['GSST001', 'D-', 'NC'], ['GSST001H', 'D-', 'NC'], ['GSST001S', 'D-', 'NC']], [['GSST020', 'D-', 'NC'], ['GSST020H', 'D-', 'NC'], ['GSST020S', 'D-', 'NC'], ['GSST021', 'D-', 'NC']]]
# [[['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC'], ['BIOL100', 'D-', 'NC'], ['ENTM100', 'D-', 'NC']]]
# [[['BCH100', 'D-', 'C'], ['BCH110A', 'D-', 'C']]]
# [[['BIOL127', 'D-', 'NC'], ['ENTM127', 'D-', 'NC']]]
# [[['CHE120', 'D-', 'NC']], [['ENVE142', 'D-', 'NC']]]
# [[['ENVE120', 'D-', 'NC']], [['ENVE142', 'D-', 'NC']]]
# [[['CHEM001C', 'D-', 'NC']], [['MATH009C', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
# [[['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM01LC', 'D-', 'NC'], ['CHEM1HLC', 'D-', 'NC']], [['ENSC002', 'D-', 'NC'], ['ENSC002H', 'D-', 'NC'], ['CEE010', 'D-', 'NC']]]
# [[['CHEM008A', 'D-', 'NC']], [['CHEM08LA', 'D-', 'NC'], ['CHEM08HA', 'D-', 'NC']], [['CHEM08HLA', 'D-', 'NC'], ['CHEM12HA', 'D-', 'NC'], ['CHEM12A', 'D-', 'NC']], [['CHEM008B', 'D-', 'NC']], [['CHEM08LB', 'D-', 'NC'], ['CHEM08HB', 'D-', 'NC']], [['CHEM08HLB', 'D-', 'NC'], ['CHEM12B', 'D-', 'NC'], ['CHEM12HB', 'D-', 'NC']]]
# [[['CHEM005', 'C-', 'NC'], ['ENSC101', 'C-', 'NC']]]
# [[['ENSC100', 'D-', 'NC']], [['ENSC101', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['STAT100B', 'D-', 'NC']]]
# [[['ENSC006', 'D-', 'NC'], ['ECON006', 'D-', 'NC'], ['ENSC143A', 'D-', 'NC'], ['ECON143A', 'D-', 'NC']], [['ENSC100', 'D-', 'NC'], ['ENSC101', 'D-', 'NC'], ['ENSC102', 'D-', 'NC']]]
# [[['CHEM001C', 'D-', 'NC']], [['CHEM01LC', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM1HLC', 'D-', 'NC']]]
# [[['CHEM008A', 'D-', 'NC']], [['CHEM08LA', 'D-', 'NC'], ['CHEM08HA', 'D-', 'NC']], [['CHEM08HLA', 'D-', 'NC'], ['CHEM12HA', 'D-', 'NC'], ['CHEM12A', 'D-', 'NC']], [['CHEM008B', 'D-', 'NC']], [['CHEM08LB', 'D-', 'NC'], ['CHEM08HB', 'D-', 'NC']], [['CHEM08HLB', 'D-', 'NC'], ['CHEM12B', 'D-', 'NC'], ['CHEM12HB', 'D-', 'NC']]]
# [[['BCH110A', 'D-', 'NC']], [['BCH110B', 'D-', 'NC']]]
# [[['MATH006A', 'C-', 'NC']]]
# [[['MATH007A', 'C-', 'NC'], ['MATH008B', 'C-', 'NC'], ['MATH009A', 'C-', 'NC'], ['MATH09HA', 'C-', 'NC']]]
# [[['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']]]
# [[['MATH007B', 'C-', 'NC'], ['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']]]
# [[['MATH010A', 'C-', 'NC']]]
# [[['MATH007A', 'D-', 'NC'], ['MATH008B', 'D-', 'NC'], ['MATH009A', 'D-', 'NC'], ['MATH09HA', 'D-', 'NC']], [['CS010', 'D-', 'NC'], ['CS010V', 'D-', 'NC'], ['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']]]
# [[['MATH007A', 'C-', 'NC'], ['MATH008B', 'C-', 'NC'], ['MATH009A', 'C-', 'NC'], ['MATH09HA', 'C-', 'NC']], [['CS010', 'C-', 'NC'], ['MATH007B', 'C-', 'NC'], ['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']]]
# [[['MATH007B', 'C-', 'NC'], ['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']]]
# [[['MATH010A', 'C-', 'NC']], [['MATH031', 'C-', 'NC']]]
# [[['MATH010A', 'C-', 'C']], [['MATH031', 'C-', 'NC']]]
# [[['MATH031', 'C-', 'NC']]]
# [[['CS010', 'C-', 'NC']], [['MATH031', 'C-', 'C']]]
# [[['MATH010A', 'C-', 'NC']]]
# [[['MATH009C', 'C-', 'NC'], ['MATH09HC', 'C-', 'NC']], [['MATH010A', 'C-', 'NC']], [['MATH031', 'C-', 'C']], [['MATH046', 'C-', 'NC']]]
# [[['MATH010A', 'C-', 'NC']], [['MATH010B', 'C-', 'NC']], [['MATH046', 'C-', 'C']]]
# [[['MATH010B', 'C-', 'NC']], [['MATH046', 'C-', 'NC']], [['MATH145A', 'C-', 'NC']]]
# [[['MATH146A', 'D-', 'NC']]]
# [[['MATH171', 'D-', 'NC']], [['MATH172', 'D-', 'NC']]]
# [[['MATH145B', 'D-', 'NC']]]
# [[['MATH146B', 'D-', 'NC']], [['MATH151B', 'D-', 'NC']]]
# [[['MATH151C', 'D-', 'NC']]]
# [[['MATH151C', 'D-', 'NC']], [['MATH165A', 'D-', 'NC']]]
# [[['MATH209C', 'D-', 'NC']]]
# [[['MATH201C', 'D-', 'NC']]]
# [[['MATH201B', 'D-', 'NC']], [['MATH232B', 'D-', 'NC']]]
# [[['MATH131', 'D-', 'NC']], [['MATH151C', 'D-', 'NC']]]
# [[['MATH205A', 'D-', 'NC']], [['MATH205B', 'D-', 'NC']], [['MATH205C', 'D-', 'NC'], ['PHYS205', 'D-', 'NC']]]
# [[['ME002', 'D-', 'NC']]]
# [[['MATH010A', 'D-', 'NC']], [['ME018', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
# [[['MATH046', 'D-', 'NC']], [['ME010', 'C-', 'NC']], [['ME018', 'D-', 'NC']]]
# [[['CHEM001B', 'D-', 'NC']], [['PHYS040C', 'D-', 'NC']]]
# [[['ME116A', 'D-', 'NC']]]
# [[['ME100A', 'D-', 'NC']], [['ME113', 'D-', 'NC']], [['ME116A', 'D-', 'NC']]]
# [[['BIEN105', 'D-', 'NC'], ['ME113', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
# [[['ME120', 'D-', 'NC']], [['ME121', 'D-', 'NC']]]
# [[['ME110', 'D-', 'NC']], [['ME114', 'D-', 'NC']]]
# [[['CS011', 'D-', 'NC'], ['MATH011', 'D-', 'NC'], ['CS120A', 'D-', 'NC'], ['EE120A', 'D-', 'NC'], ['CS150', 'D-', 'NC'], ['PHIL008', 'D-', 'NC'], ['PHIL008H', 'D-', 'NC']]]
# [[['PHIL001', 'D-', 'NC'], ['PHIL001H', 'D-', 'NC'], ['PHIL002', 'D-', 'NC'], ['PHIL002H', 'D-', 'NC'], ['PHIL003', 'D-', 'NC'], ['PHIL003H', 'D-', 'NC'], ['PHIL003W', 'D-', 'NC'], ['PHIL003X', 'D-', 'NC'], ['PHIL004', 'D-', 'NC'], ['PHIL005', 'D-', 'NC'], ['PHIL006', 'D-', 'NC'], ['PHIL007', 'D-', 'NC'], ['PHIL007H', 'D-', 'NC'], ['PHIL008', 'D-', 'NC'], ['PHIL008H', 'D-', 'NC'], ['PHIL009', 'D-', 'NC'], ['PHIL009H', 'D-', 'NC'], ['PHIL010', 'D-', 'NC'], ['PHIL010H', 'D-', 'NC'], ['PHIL012', 'D-', 'NC'], ['PHIL030E', 'D-', 'NC'], ['PHIL030F', 'D-', 'NC'], ['PHIL030G', 'D-', 'NC'], ['PHIL030I', 'D-', 'NC'], ['PHIL030J', 'D-', 'NC'], ['PHIL030K', 'D-', 'NC'], ['PHIL030M', 'D-', 'NC'], ['PHIL030N', 'D-', 'NC']]]
# [[['MATH009A', 'C-', 'NC'], ['MATH09HA', 'C-', 'NC'], ['MATH008B', 'C-', 'NC']]]
# [[['MATH009A', 'D-', 'NC'], ['MATH09HA', 'D-', 'NC'], ['MATH022', 'D-', 'NC']]]
# [[['ECON002', 'D-', 'NC']]]
# [[['ECON003', 'C-', 'NC']], [['MATH009A', 'D-', 'NC'], ['MATH09HA', 'D-', 'NC']]]
# [[['ECON002', 'D-', 'NC']]]
# [[['ECON101', 'D-', 'NC']], [['ECON002', 'D-', 'NC'], ['ECON003', 'D-', 'NC']]]
# [[['ECON104B', 'D-', 'NC']], [['MATH010A', 'D-', 'NC']], [['MATH131', 'D-', 'NC']]]
# [[['ECON002', 'D-', 'NC'], ['ECON002H', 'D-', 'NC'], ['ECON003', 'D-', 'NC'], ['ECON004', 'D-', 'NC']]]
# [[['ECON002', 'D-', 'NC']], [['ECON003', 'D-', 'NC']]]
# [[['ECON102', 'D-', 'NC'], ['ECON104A', 'D-', 'NC']]]
# [[['BUS020', 'D-', 'NC']], [['ECON002', 'D-', 'NC']], [['ECON003', 'D-', 'NC']], [['ECON101', 'D-', 'NC'], ['STAT048', 'D-', 'NC']]]
# [[['ECON002', 'D-', 'NC']], [['ECON003', 'D-', 'NC']]]
# [[['ECON102', 'D-', 'NC'], ['ECON104A', 'D-', 'NC']]]
# [[['ECON003', 'D-', 'NC']]]
# [[['ECON102', 'D-', 'NC'], ['ECON104A', 'D-', 'NC']]]
# [[['ECON101', 'D-', 'NC']], [['ECON104B', 'D-', 'NC']]]
# [[['ECON102', 'D-', 'NC'], ['ECON104A', 'D-', 'NC']]]
# [[['ECON102', 'D-', 'NC'], ['ECON104A', 'D-', 'NC']], [['ECON107', 'D-', 'NC']]]
# [[['ECON104B', 'D-', 'NC']]]
# [[['ECON105B', 'D-', 'NC']]]
# [[['ECON104A', 'D-', 'NC']], [['ECON105A', 'D-', 'NC']], [['MATH009A', 'D-', 'NC']], [['MATH009B', 'D-', 'NC']], [['STAT100B', 'D-', 'NC']]]
# [[['ECON205B', 'D-', 'NC']]]
# [[['EDUC241A', 'D-', 'NC']]]
# [[['EDUC215A', 'D-', 'NC']]]
# [[['MATH046', 'D-', 'C']], [['PHYS040C', 'D-', 'C']]]
# [[['EE001A', 'D-', 'NC']], [['EE01LA', 'D-', 'NC']]]
# [[['EE001B', 'D-', 'NC']]]
# [[['EE020', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['EE001B', 'D-', 'C']]]
# [[['EE110B', 'D-', 'NC']]]
# [[['CS061', 'C-', 'NC']]]
# [[['EE100B', 'D-', 'C']], [['CS120B', 'D-', 'C'], ['EE120B', 'D-', 'C']]]
# [[['EE100A', 'D-', 'NC']]]
# [[['PHYS040C', 'D-', 'NC']]]
# [[['PHYS040C', 'D-', 'NC']]]
# [[['EE110B', 'D-', 'NC']]]
# [[['EE001B', 'D-', 'NC']], [['EE116', 'D-', 'NC']]]
# [[['CS120B', 'D-', 'NC'], ['EE120B', 'D-', 'NC']]]
# [[['BUS020', 'C-', 'NC']]]
# [[['ENGL001B', 'C', 'NC']]]
# [[['CS008', 'D-', 'NC']]]
# [[['CS008', 'D-', 'NC']], [['STAT048', 'D-', 'NC'], ['STAT100A', 'D-', 'NC']]]
# [[['BUS104', 'D-', 'NC'], ['STAT104', 'D-', 'NC']]]
# [[['BUS020', 'D-', 'NC']], [['ECON002', 'D-', 'NC']], [['ECON003', 'D-', 'NC']], [['ECON101', 'D-', 'NC'], ['STAT048', 'D-', 'NC']]]
# [[['BUS020', 'D-', 'NC']]]
# [[['BUS103', 'D-', 'NC']]]
# [[['BUS103', 'D-', 'NC']]]
# [[['BUS103', 'D-', 'NC']]]
# [[['BUS103', 'D-', 'NC']]]
# [[['BUS103', 'D-', 'NC']]]
# [[['BUS105', 'D-', 'NC']]]
# [[['BUS106', 'C-', 'NC'], ['ECON134', 'C-', 'NC']], [['BUS132', 'C-', 'NC']]]
# [[['BUS020', 'D-', 'NC']], [['ECON101', 'D-', 'NC'], ['STAT048', 'D-', 'NC']], [['ECON102', 'D-', 'NC'], ['ECON103', 'D-', 'NC'], ['ECON104A', 'D-', 'NC'], ['ECON105A', 'D-', 'NC']]]
# [[['BUS106', 'C-', 'NC'], ['ECON134', 'C-', 'NC']], [['BUS132', 'C-', 'NC']]]
# [[['BUS106', 'D-', 'NC'], ['ECON134', 'D-', 'NC']]]
# [[['BUS107', 'D-', 'NC']]]
# [[['ECON102', 'D-', 'NC'], ['ECON104A', 'D-', 'NC']]]
# [[['BUS021', 'D-', 'NC']]]
# [[['BUS165B', 'D-', 'NC']]]
# [[['BUS101', 'D-', 'NC']], [['BUS108', 'D-', 'NC']]]
# [[['BUS108', 'D-', 'NC']]]
# [[['BUS165B', 'D-', 'NC']]]
# [[['BUS101', 'D-', 'NC']]]
# [[['BUS103', 'D-', 'NC']], [['ECON003', 'D-', 'NC']]]
# [[['ECON102', 'D-', 'NC'], ['ECON104A', 'D-', 'NC']]]
# [[['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC']], [['BCH100', 'D-', 'C'], ['BCH110A', 'D-', 'C']]]
# [[['BIOL005A', 'C-', 'NC']], [['BIOL005B', 'C-', 'NC']], [['CHEM001A', 'D-', 'NC'], ['CHEM01HA', 'D-', 'NC']], [['CHEM001B', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC']]]
# [[['CBNS120', 'D-', 'C'], ['PSYC120', 'D-', 'C']]]
# [[['CBNS106', 'D-', 'NC']]]
# [[['CBNS106', 'C-', 'NC']]]
# [[['BIOL005C', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['BCH100', 'D-', 'NC'], ['BCH110A', 'D-', 'NC']]]
# [[['EE117', 'D-', 'NC']]]
# [[['EE215', 'D-', 'NC']]]
# [[['CHEM001A', 'D-', 'NC'], ['CHEM01HA', 'D-', 'NC']], [['CS010', 'D-', 'NC'], ['CS030', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
# [[['MATH010A', 'D-', 'NC']], [['CS010', 'D-', 'NC'], ['EE020', 'D-', 'NC'], ['ME018', 'D-', 'NC']]]
# [[['ENGL001B', 'C', 'NC']]]
# [[['ENGL001A', 'C', 'NC'], ['ENGL01PA', 'C', 'NC']]]
# [[['ENGL001B', 'C', 'NC']]]
# [[['ENGL001B', 'C', 'NC']]]
# [[['ME009', 'D-', 'NC']]]
# [[['ME175A', 'D-', 'C']], [['ME113', 'D-', 'NC']], [['ME116A', 'D-', 'NC']], [['ME170A', 'D-', 'NC']], [['ME174', 'D-', 'NC']]]
# [[['ME110', 'D-', 'NC']], [['ME114', 'D-', 'NC']]]
# [[['ART003', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL05LA', 'D-', 'NC'], ['BIOL020', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['BCH100', 'D-', 'NC'], ['BCH110A', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['BIOL05LA', 'D-', 'NC'], ['BIOL020', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['BCH100', 'D-', 'C'], ['BCH110A', 'D-', 'C']]]
# [[['BCH110C', 'D-', 'NC'], ['BIOL107A', 'D-', 'NC']], [['BIOL102', 'D-', 'NC']]]
# [[['MUS010', 'D-', 'NC']], [['MUS031A', 'D-', 'C']]]
# [[['MUS001', 'D-', 'NC'], ['MUS010', 'D-', 'NC']]]
# [[['MUS030A', 'D-', 'NC']], [['MUS030B', 'D-', 'NC']], [['MUS030C', 'D-', 'NC']]]
# [[['MUS031C', 'D-', 'NC']]]
# [[['MUS030A', 'D-', 'NC']], [['MUS030B', 'D-', 'NC']], [['MUS030C', 'D-', 'NC']]]
# [[['MUS030A', 'D-', 'NC']], [['MUS030B', 'D-', 'NC']], [['MUS030C', 'D-', 'NC']]]
# [[['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']]]
# [[['BIOL005A', 'C-', 'NC']], [['BIOL020', 'C-', 'NC'], ['BIOL05LA', 'C-', 'NC']], [['BIOL005B', 'C-', 'NC']]]
# [[['BIOL005C', 'D-', 'NC']]]
# [[['BIOL005C', 'C-', 'NC']], [['BIOL102', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['BCH100', 'D-', 'NC'], ['BCH110A', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC']], [['MATH09HB', 'D-', 'NC'], ['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['BCH100', 'D-', 'NC'], ['BCH110A', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']]]
# [[['BIOL005C', 'C-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']]]
# [[['BIOL005C', 'C-', 'NC']], [['BIOL102', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['BCH100', 'D-', 'NC'], ['BCH110A', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL05LA', 'D-', 'NC'], ['BIOL020', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['BCH100', 'D-', 'NC'], ['BCH110A', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['BIOL05LA', 'D-', 'NC'], ['BIOL020', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['BCH100', 'D-', 'C'], ['BCH110A', 'D-', 'C']]]
# [[['BCH100', 'D-', 'NC'], ['BCH110A', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['BIOL05LA', 'D-', 'NC'], ['BIOL020', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['BCH100', 'D-', 'NC'], ['BCH110A', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['BCH100', 'D-', 'C'], ['BCH110A', 'D-', 'C']], [['BIOL104', 'D-', 'NC'], ['BPSC104', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['BCH100', 'D-', 'NC'], ['BCH110A', 'D-', 'NC']]]
# [[['BIOL005A', 'C-', 'NC']], [['BIOL005B', 'C-', 'NC']], [['BIOL005C', 'C-', 'NC']], [['CHEM001C', 'C-', 'NC'], ['CHEM01HC', 'C-', 'NC']], [['CHEM008A', 'C-', 'NC']], [['CHEM08LA', 'C-', 'NC'], ['CHEM08HA', 'C-', 'NC']], [['CHEM08HLA', 'C-', 'NC'], ['CHEM12HA', 'C-', 'NC'], ['CHEM12A', 'C-', 'NC']], [['MATH007B', 'C-', 'NC'], ['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']], [['PHYS002A', 'C-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC'], ['BIOL100', 'D-', 'NC'], ['ENTM100', 'D-', 'NC']]]
# [[['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['MATH09HB', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC']]]
# [[['BCH110A', 'D-', 'C'], ['BCH110B', 'D-', 'C']], [['BIOL102', 'D-', 'NC']], [['BIOL107A', 'D-', 'NC']]]
# [[['BCH110C', 'D-', 'NC'], ['BIOL107A', 'D-', 'NC']], [['BIOL102', 'D-', 'NC']]]
# [[['BMSC232', 'D-', 'C']]]
# [[['BIOL005C', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['BCH100', 'D-', 'C'], ['BCH110A', 'D-', 'C']], [['BIOL104', 'D-', 'NC'], ['BPSC104', 'D-', 'NC']]]
# [[['BIOL104', 'D-', 'NC'], ['BPSC104', 'D-', 'NC'], ['BIOL116', 'D-', 'NC']], [['STAT100A', 'D-', 'NC']]]
# [[['BCH110A', 'D-', 'NC']], [['BCH110B', 'D-', 'NC'], ['BCH100', 'D-', 'NC']]]
# [[['BIOL107A', 'D-', 'NC'], ['BIOL143', 'D-', 'NC'], ['BPSC143', 'D-', 'NC'], ['BCH100', 'D-', 'NC'], ['CBNS101', 'D-', 'NC']]]
# [[['MATH009C', 'D-', 'NC'], ['MATH09HC', 'D-', 'NC']], [['STAT110', 'D-', 'NC'], ['STAT231A', 'D-', 'NC']]]
# [[['CHEM001C', 'B', 'NC']], [['CHEM01LC', 'B', 'NC'], ['CHEM01HC', 'B', 'NC']], [['CHEM1HLC', 'B', 'NC']]]
# [[['CHEM001C', 'C-', 'NC'], ['CHEM01HC', 'C-', 'NC']], [['CHEM01LC', 'C-', 'NC'], ['CHEM1HLC', 'C-', 'NC']], [['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']]]
# [[['CHEM001C', 'C-', 'NC'], ['CHEM01HC', 'C-', 'NC']], [['CHEM01LC', 'C-', 'NC'], ['CHEM1HLC', 'C-', 'NC']], [['MATH010A', 'C-', 'C'], ['MATH009A', 'C-', 'NC'], ['MATH09HC', 'C-', 'NC']], [['PHYS002C', 'C-', 'NC'], ['PHYS040C', 'C-', 'C']]]
# [[['CHEM005', 'C-', 'NC']], [['PHYS002C', 'D-', 'C'], ['PHYS040C', 'D-', 'C']]]
# [[['CHEM008A', 'D-', 'NC']], [['CHEM08LA', 'D-', 'NC'], ['CHEM08HA', 'D-', 'NC']], [['CHEM08HLA', 'D-', 'NC'], ['CHEM12HA', 'D-', 'NC'], ['CHEM12A', 'D-', 'NC']], [['CHEM008B', 'D-', 'NC']], [['CHEM08LB', 'D-', 'NC'], ['CHEM08HB', 'D-', 'NC']], [['CHEM08HLB', 'D-', 'NC'], ['CHEM12HB', 'D-', 'NC'], ['CHEM12B', 'D-', 'NC']]]
# [[['CHEM005', 'C-', 'NC'], ['ENSC104', 'C-', 'NC']]]
# [[['CHEM113', 'C', 'NC']]]
# [[['CHEM110A', 'C', 'NC']], [['CHEM110B', 'C', 'NC']]]
# [[['CHEM125', 'D-', 'NC']]]
# [[['CHEM125', 'D-', 'NC']]]
# [[['CHEM150A', 'D-', 'NC']], [['CHEM150B', 'D-', 'NC']]]
# [[['CHN002', 'C-', 'NC']]]
# [[['CHN003', 'C-', 'NC']]]
# [[['CHN002', 'C-', 'NC'], ['CHN020A', 'C-', 'NC']]]
# [[['CHN006', 'D-', 'NC'], ['CHN025', 'D-', 'NC']]]
# [[['CHN102', 'D-', 'NC']]]
# [[['BIOL005A', 'C-', 'NC']], [['CHEM008C', 'C-', 'NC']], [['CHEM08LC', 'C-', 'NC'], ['CHEM08HC', 'C-', 'NC']], [['CHEM08HLC', 'C-', 'NC'], ['CHEM12HC', 'C-', 'NC'], ['CHEM12C', 'C-', 'NC']]]
# [[['BCH100', 'C-', 'NC'], ['BCH110B', 'C-', 'NC']], [['BIOL102', 'D-', 'NC']]]
# [[['BCH110A', 'D-', 'NC']], [['BCH110B', 'D-', 'NC'], ['BCH100', 'D-', 'NC']]]
# [[['BCH110A', 'D-', 'NC']], [['BCH110B', 'D-', 'NC']], [['BCH110C', 'D-', 'NC']], [['BCH184', 'D-', 'NC']], [['CHEM109', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['CHEM008A', 'D-', 'NC']], [['CHEM08LA', 'D-', 'NC'], ['CHEM08HA', 'D-', 'NC']], [['CHEM08HLA', 'D-', 'NC'], ['CHEM12A', 'D-', 'NC'], ['CHEM12HA', 'D-', 'NC']], [['MATH046', 'D-', 'NC']]]
# [[['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CS010', 'D-', 'NC']], [['MATH010A', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
# [[['BIEN101', 'D-', 'NC']], [['MATH010B', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['PHYS040C', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']]]
# [[['BIEN105', 'D-', 'NC']], [['BIOL002', 'D-', 'NC'], ['BIOL005A', 'D-', 'NC']]]
# [[['BIEN155', 'C-', 'C']], [['BIEN010', 'C-', 'NC']], [['BIEN130L', 'C-', 'NC']]]
# [[['BIEN110', 'D-', 'NC']], [['BIEN140A', 'D-', 'NC']], [['BIOL005A', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']]]
# [[['CHEM001A', 'C-', 'NC']], [['CHEM01LA', 'C-', 'NC'], ['CHEM01HA', 'C-', 'NC']], [['CHEM1HLA', 'C-', 'NC']]]
# [[['BIOL005A', 'C-', 'NC']], [['BIOL020', 'C-', 'NC'], ['BIOL05LA', 'C-', 'NC']], [['CHEM001A', 'D-', 'NC'], ['CHEM01HA', 'D-', 'NC']], [['CHEM001B', 'D-', 'NC'], ['CHEM01HB', 'D-', 'NC']]]
# [[['BIOL005A', 'C-', 'NC']], [['BIOL020', 'C-', 'NC'], ['BIOL05LA', 'C-', 'NC']], [['BIOL005B', 'C-', 'NC']], [['MATH009A', 'C-', 'NC'], ['MATH09HA', 'C-', 'NC'], ['MATH008B', 'C-', 'NC']]]
# [[['ENGL001B', 'C', 'NC']]]
# [[['ENGL001B', 'C', 'NC']]]
# [[['ITAL003', 'C-', 'NC'], ['ITAL020B', 'C-', 'NC']]]
# [[['JPN002', 'C-', 'NC']]]
# [[['JPN003', 'C-', 'NC'], ['JPN010B', 'C-', 'NC']]]
# [[['JPN006', 'D-', 'NC']]]
# [[['KOR003', 'C-', 'NC']]]
# [[['LATN003', 'C-', 'NC']]]
# [[['SPN110', 'D-', 'NC']]]
# [[['LING111', 'D-', 'NC']], [['LING121', 'D-', 'NC'], ['LING141', 'D-', 'NC']]]
# [[['LING111', 'D-', 'NC']], [['LING121', 'D-', 'NC'], ['LING141', 'D-', 'NC']]]
# [[['MGT403', 'D-', 'NC']]]
# [[['MGT201', 'D-', 'NC']], [['MGT211', 'D-', 'NC']]]
# [[['MGT211', 'D-', 'NC']]]
# [[['MGT207', 'D-', 'NC']]]
# [[['MGT200', 'D-', 'NC']]]
# [[['MGT209', 'D-', 'NC']]]
# [[['MGT204', 'D-', 'NC']]]
# [[['MGT202', 'D-', 'NC']]]
# [[['MGT211', 'D-', 'NC']]]
# [[['MGT204', 'D-', 'NC']]]
# [[['MGT202', 'D-', 'NC'], ['MGT209', 'D-', 'NC']]]
# [[['MSE160', 'D-', 'NC']]]
# [[['CHEM110A', 'C', 'NC']], [['CHEM110B', 'C', 'NC']]]
# [[['MATH046', 'D-', 'NC']], [['PHYS040A', 'D-', 'NC']]]
# [[['PHYS221C', 'D-', 'NC']]]
# [[['ME110', 'D-', 'NC']], [['ME114', 'D-', 'NC']]]
# [[['CHEM150A', 'D-', 'NC']], [['CHEM150B', 'D-', 'NC']]]
# [[['BCH110A', 'D-', 'C'], ['BCH110B', 'D-', 'C']], [['BIOL102', 'D-', 'NC']], [['BIOL107A', 'D-', 'NC']]]
# [[['BIOL102', 'D-', 'NC']]]
# [[['CHEM001C', 'D-', 'NC']], [['MATH046', 'D-', 'C']], [['PHYS040B', 'D-', 'NC']]]
# [[['CHEM001C', 'D-', 'NC']], [['MATH009C', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
# [[['CHE110A', 'D-', 'NC'], ['ENVE171', 'D-', 'NC']], [['MATH010A', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
# [[['CHE116', 'D-', 'NC']], [['CHE120', 'D-', 'NC']]]
# [[['BIOL121', 'D-', 'C'], ['MCBL121', 'D-', 'C']], [['BCH110A', 'D-', 'NC']], [['CHE120', 'D-', 'NC']], [['CHE122', 'D-', 'NC']]]
# [[['CHEM008A', 'D-', 'NC']], [['CHEM08LA', 'D-', 'NC'], ['CHEM08HA', 'D-', 'NC']], [['CHEM08HLA', 'D-', 'NC'], ['CHEM12HA', 'D-', 'NC'], ['CHEM12A', 'D-', 'NC']], [['PHYS040C', 'D-', 'NC']]]
# [[['ENGR118', 'D-', 'NC']]]
# [[['CHE130', 'D-', 'NC'], ['ENVE130', 'D-', 'NC']]]
# [[['CHEM001B', 'C-', 'NC'], ['CHEM01HB', 'C-', 'NC']], [['CHEM01LB', 'C-', 'NC'], ['CHEM1HLB', 'C-', 'NC']]]
# [[['MATH005', 'D-', 'C'], ['MATH006A', 'D-', 'C']]]
# [[['CHEM001C', 'C-', 'NC']], [['CHEM01LC', 'C-', 'NC'], ['CHEM01HC', 'C-', 'NC']], [['CHEM1HLC', 'C-', 'NC']]]
# [[['CHEM008B', 'C-', 'NC']], [['CHEM08LB', 'C-', 'NC'], ['CHEM08HB', 'C-', 'NC']], [['CHEM08HLB', 'C-', 'NC'], ['CHEM12B', 'C-', 'NC'], ['CHEM12HB', 'C-', 'NC']]]
# [[['SOC001', 'D-', 'NC'], ['SOC001H', 'D-', 'NC']]]
# [[['SOC001', 'C-', 'NC'], ['SOC001H', 'C-', 'NC']]]
# [[['SOC001', 'C-', 'NC'], ['SOC001H', 'C-', 'NC']]]
# [[['SOC004', 'C-', 'NC']]]
# [[['SOC005', 'C-', 'NC']]]
# [[['SOC001', 'D-', 'NC'], ['SOC001H', 'D-', 'NC']]]
# [[['SOC001', 'D-', 'NC'], ['SOC001H', 'D-', 'NC']]]
# [[['SOC005', 'C-', 'NC']]]
# [[['SOC001', 'C', 'NC'], ['SOC001H', 'C', 'NC']], [['SOC004', 'C', 'NC']]]
# [[['SOC001', 'D-', 'NC'], ['SOC001H', 'D-', 'NC']]]
# [[['SOC003', 'C-', 'NC']], [['SOC005', 'C-', 'NC']]]
# [[['SOC001', 'C', 'NC']], [['SOC004', 'C', 'NC']], [['SOC005', 'C', 'NC'], ['SOC001H', 'C', 'NC']]]
# [[['SPN001', 'C-', 'NC']]]
# [[['SPN002', 'C-', 'NC']]]
# [[['SPN003', 'C-', 'NC']]]
# [[['SPN004', 'D-', 'NC']]]
# [[['SPN005', 'D-', 'NC']]]
# [[['SPN006', 'D-', 'NC']]]
# [[['SPN101B', 'D-', 'NC'], ['SPN109B', 'D-', 'NC']]]
# [[['LING020', 'D-', 'NC']], [['SPN101A', 'D-', 'NC']], [['SPN101B', 'D-', 'NC'], ['SPN109A', 'D-', 'NC']], [['SPN109B', 'D-', 'NC']]]
# [[['SPN109A', 'D-', 'NC']]]
# [[['SPN101A', 'D-', 'NC']], [['SPN101B', 'D-', 'NC'], ['SPN109A', 'D-', 'NC']], [['SPN109B', 'D-', 'NC']]]
# [[['SPN110', 'D-', 'NC']]]
# [[['SPN110', 'D-', 'NC']]]
# [[['SPN110', 'D-', 'NC']]]
# [[['SPN110', 'D-', 'NC']]]
# [[['SPN110', 'D-', 'NC']]]
# [[['CS008', 'D-', 'NC']], [['MATH004', 'D-', 'NC'], ['MATH005', 'D-', 'NC'], ['MATH006B', 'D-', 'NC'], ['MATH007A', 'D-', 'NC'], ['MATH009A', 'D-', 'NC'], ['MATH09HA', 'D-', 'NC']]]
# [[['MATH005', 'D-', 'NC'], ['MATH006B', 'D-', 'NC'], ['MATH007A', 'D-', 'NC'], ['MATH009A', 'D-', 'NC'], ['MATH09HA', 'D-', 'NC']]]
# [[['STAT100A', 'C-', 'NC']]]
# [[['CS008', 'D-', 'NC']], [['STAT048', 'D-', 'NC'], ['STAT100A', 'D-', 'NC']]]
# [[['STAT100B', 'D-', 'NC']]]
# [[['STAT100B', 'D-', 'NC']]]
# [[['STAT100A', 'D-', 'NC']]]
# [[['MATH009C', 'D-', 'C'], ['MATH09HC', 'D-', 'C']]]
# [[['MATH009C', 'D-', 'C'], ['MATH09HC', 'D-', 'C']]]
# [[['STAT157', 'D-', 'NC']], [['STAT160C', 'D-', 'NC']]]
# [[['MATH010B', 'D-', 'NC']], [['STAT160C', 'D-', 'NC']]]
# [[['STAT170A', 'D-', 'NC']]]
# [[['STAT160C', 'D-', 'NC']]]
# [[['STAT201C', 'D-', 'NC']]]
# [[['STAT100B', 'D-', 'NC']]]
# [[['STAT160A', 'D-', 'NC']], [['STAT160B', 'D-', 'NC']], [['STAT160C', 'D-', 'NC']]]
# [[['STAT160C', 'D-', 'NC']], [['STAT170B', 'D-', 'NC']], [['STAT171', 'D-', 'NC']]]
# [[['Theater, Film & Digital Prod 109', 'D', 'NC']]]
# [[['CRWT066', 'D-', 'NC'], ['MCS066', 'D-', 'NC'], ['Theater, Film & Digital Prod 066', 'D-', 'NC']]]
# [[['CRWT066', 'D-', 'NC'], ['MCS066', 'D-', 'NC'], ['Theater, Film & Digital Prod 066', 'D-', 'NC']]]
# [[['VNM003', 'C-', 'NC'], ['VNM020B', 'C-', 'NC']]]
# [[['MATH009B', 'D-', 'C'], ['MATH09HB', 'D-', 'C']], [['PHYS002A', 'C-', 'NC']]]
# [[['MATH008B', 'C-', 'NC'], ['MATH009A', 'C-', 'NC'], ['MATH09HA', 'C-', 'NC']], [['MATH009B', 'D-', 'C'], ['MATH09HB', 'D-', 'C']]]
# [[['PHYS040B', 'C-', 'NC']], [['MATH009C', 'D-', 'NC'], ['MATH09HC', 'D-', 'NC']]]
# [[['MATH009A', 'C-', 'C'], ['MATH09HA', 'C-', 'C']]]
# [[['MATH010B', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['PHYS040D', 'C-', 'NC'], ['PHYS041C', 'C-', 'NC'], ['PHYS002C', 'B-', 'NC']]]
# [[['MATH009C', 'D-', 'NC']], [['MATH010A', 'D-', 'C']], [['PHYS002A', 'B-', 'NC'], ['PHYS040A', 'C-', 'NC'], ['PHYS041A', 'C-', 'NC']]]
# [[['MATH010B', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['PHYS002B', 'B-', 'NC'], ['PHYS040C', 'C-', 'NC'], ['PHYS041B', 'C-', 'NC']]]
# [[['PHYS002B', 'B-', 'NC'], ['PHYS040C', 'C-', 'NC'], ['PHYS041B', 'C-', 'NC']]]
# [[['PHYS002B', 'B-', 'NC'], ['PHYS040E', 'C-', 'NC'], ['PHYS041C', 'C-', 'NC']]]
# [[['MATH010B', 'D-', 'NC']], [['MATH046', 'D-', 'C']], [['PHYS130B', 'D-', 'NC']], [['PHYS002C', 'B-', 'NC'], ['PHYS040E', 'C-', 'NC'], ['PHYS041C', 'C-', 'NC']]]
# [[['PHYS135B', 'D-', 'NC']], [['PHYS156A', 'D-', 'NC']]]
# [[['PHYS221A', 'D-', 'NC']], [['PHYS221B', 'D-', 'NC']], [['PHYS221C', 'D-', 'NC']]]
# [[['PHYS221A', 'D-', 'NC']], [['PHYS221B', 'D-', 'NC']], [['PHYS221C', 'D-', 'NC']]]
# [[['PHYS221C', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL05LA', 'D-', 'NC'], ['BIOL020', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['BCH100', 'D-', 'NC'], ['BCH110A', 'D-', 'NC']]]
# [[['BIOL005A', 'D-', 'NC']], [['BIOL005B', 'D-', 'NC']], [['BIOL005C', 'D-', 'NC']], [['BIOL05LA', 'D-', 'NC'], ['BIOL020', 'D-', 'NC']], [['CHEM001C', 'D-', 'NC'], ['CHEM01HC', 'D-', 'NC']], [['CHEM008C', 'D-', 'NC']], [['CHEM08LC', 'D-', 'NC'], ['CHEM08HC', 'D-', 'NC']], [['CHEM08HLC', 'D-', 'NC'], ['CHEM12C', 'D-', 'NC'], ['CHEM12HC', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['BCH100', 'D-', 'NC'], ['BCH110A', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']]]
# [[['BIOL110C', 'D-', 'NC'], ['BIOL107A', 'D-', 'NC']], [['BIOL102', 'D-', 'NC']]]

# %%
### RENDER GRAPH {

def undergradOnly(courseList):
    numbers = set('0123456789')
    return [x for x in courseList if [y for y in x.courseName if y in numbers][0] in {'0','1'}]

def selectMajor(courseList,major):
    # Use 4-code for major (eg 'PHYS')
    return [x for x in courseList if x.subject == major]
    # return [x for x in courseList if x.subject in ['PHYS','ME','SOC','CHEM','CS','EE','ENSC','BIOL','BUS','DNCE','PSYC']]

len(courseList)
len(selectMajor(courseList,'PHYS'))

major = 'POSC'
if REMOVEGRADCLASS:
    majorList = undergradOnly(selectMajor(courseList,major))
else:
    majorList = selectMajor(courseList,major)

if DARKTHEME:
    dot = Digraph(comment='classflow test',graph_attr={'rankdir': 'LR', 'ranksep': '2', 'overlap': 'false', 'bgcolor':DARKTHEMECOLORS['background']})
else:
    dot = Digraph(comment='classflow test',graph_attr={'rankdir': 'LR', 'ranksep': '2', 'overlap': 'false'})

# Robustly add new classes (on a new line) to the labels inside the nodes
def safeAddLabel(course_name, new_prereq):
    # Check to see if the node already has a label
    dotline = [x for x in dot.__dict__['body'] if x.split(' ')[0][1:] == course_name and 'label=' in x]
    if dotline: # If non-empty, then node already has a label
        dotline = dotline[-1] # We want the most recent label written
        def addPrereqHTML(label,new_prereq):
            posn = label.index('</FONT')
            return label[:posn] + '<br />' + new_prereq + label[posn:]
        # I have literally no idea why the ']' bug happens; I think it's a dot issue
        newlabel = addPrereqHTML(dotline[dotline.index('label=')+6:] if dotline[-1] != ']' else dotline[dotline.index('label=')+6:-1],new_prereq)
        dot.node(course_name,label=newlabel)
    else: # No current label (or node doesn't exist), so initialize it
        dot.node(course_name,label='<' + course_name + '<br /><FONT POINT-SIZE="10">' + new_prereq +'</FONT>>')

# Define how to draw between courses (with all the relevant conditions)
def requisiteLine(fromCourse,toCourse,graph,fromOrGroup=False,**args):
    """fromCourse example: "['ANTH001', 'D-', 'NC']"
       toCourse example: "course" object with courseName, etc.
       Creates nodes on both ends, then draws the requisite line between the two of them.
       Also references the global required list"""
    
    shape = 'box'
    
    ### ALTERNATE ROUTE: If one of the edges isn't a part of the major, instead make a label under the
    ### class pointed to, then ignore the edge initialization
    if remove_nonmajor:
        # Uses same code as not remove_nonmajor, but intelligently changes the iterator
        numbers = set('0123456789')
        for i,x in enumerate(fromCourse[0]):
            if x in numbers:
                index = i
                break
        condition = fromCourse[0][:index]
        iterator = [fromCourse[0],toCourse.courseName] if condition == major else [toCourse.courseName]
        # Create nodes
        if REQUIREMENTCOLOR:
            for toNode in iterator:
                if toNode in required:
                    graph.node(toNode,style='filled',color='gold',shape=shape)
                else:
                    graph.node(toNode,style='filled',color='lightblue2',shape=shape)
        else:
            for toNode in iterator:
                if DARKTHEME:
                    graph.node(toNode,shape=shape,style='filled',color=DARKTHEMECOLORS['boxes'],fontcolor=DARKTHEMECOLORS['textcolor'])
                else:
                    graph.node(toNode,shape=shape)
        
        # Since edge auto-creates nodes, now only run if len(iterator) == 2.
        if len(iterator) == 2:
            if DARKTHEME:
                graph.edge(fromCourse[0],toCourse.courseName,color=DARKTHEMECOLORS['lines'],**args)
            else:
                graph.edge(fromCourse[0],toCourse.courseName,color='black',**args)
        else: # If not, add a label for the missing class (unless already written as a part of the orGroup)
            if not fromOrGroup:
                safeAddLabel(toCourse.courseName,fromCourse[0])
        
    else:
        # Create nodes
        if REQUIREMENTCOLOR:
            for toNode in [fromCourse[0],toCourse.courseName]:
                if toNode in required:
                    graph.node(toNode,style='filled',color='gold',shape=shape)
                else:
                    graph.node(toNode,style='filled',color='lightblue2',shape=shape)
        else:
            for toNode in [fromCourse[0],toCourse.courseName]:
                if DARKTHEME:
                    graph.node(toNode,shape=shape,style='filled',color=DARKTHEMECOLORS['boxes'],fontcolor=DARKTHEMECOLORS['textcolor'])
                else:
                    graph.node(toNode,shape=shape)
        # Draw line
        if DARKTHEME:
            graph.edge(fromCourse[0],toCourse.courseName,color=DARKTHEMECOLORS['lines'],**args)
        else:
            graph.edge(fromCourse[0],toCourse.courseName,color='black',**args)

# Create lines between courses
runID = 0
for _class in majorList:
    if _class.preReq != dict():
        # _class.preReq is an "and_group"
        for orGroup in _class.preReq:
            if len(orGroup) > 1:
                for _prereq in orGroup:
                    requisiteLine(_prereq,_class,dot,style='dashed', fromOrGroup=True)
                # Now add the or group as a prereq under the node
                # Be careful to not overwrite other labels; automatically do a <BR /> if needed.
                safeAddLabel(_class.courseName,' or '.join([x[0] for x in orGroup]))
            else:
                requisiteLine(orGroup[0],_class,dot)

# dot.node('PHYS111',label='PHYS111')
# safeAddLabel()
dot

# %%
dot.render(filename='./test',view=True,format='png')
# Out:
# './test.png'

# %%
with open('/home/order/Dropbox/Python_Code/Cloned/ucr-course-graph/data/subjects.json') as f:
    codes = json.load(f)
lookup = {x['description']:x['code'] for x in codes}
print(lookup)
# Out:
# {'Academic Resource Center': 'ARC', 'Anthropology': 'ANTH', 'Arabic Language': 'ARBC', 'Art': 'ART', 'Art History': 'AHS', 'Asian Studies': 'AST', 'Basic Writing': 'BSWT', 'Biochemistry': 'BCH', 'Bioengineering': 'BIEN', 'Biology': 'BIOL', 'Biomedical Sciences': 'BMSC', 'Botany/Plant Science': 'BPSC', 'Business': 'BUS', 'CHASS First Yr Experience Prog': 'CHFY', 'Cell Biology and Neuroscience': 'CBNS', 'Cell, Molecular, and Develpmnt': 'CMDB', 'Chemical Engineering': 'CHE', 'Chemical and Environmental Eng': 'CEE', 'Chemistry': 'CHEM', 'Chinese': 'CHN', 'Classical Studies': 'CLA', 'Comparative Ancient Civilizatn': 'CPAC', 'Comparative Literature': 'CPLT', 'Computer Science': 'CS', 'Creative Writing': 'CRWT', 'Crwt Wrt &amp; Wrt for Perf Arts': 'CWPA', 'Dance': 'DNCE', 'Economics': 'ECON', 'Education': 'EDUC', 'Electrical Engineering': 'EE', 'Engineering': 'ENGR', 'English': 'ENGL', 'Entomology': 'ENTM', 'Environmental Engineering': 'ENVE', 'Environmental Sciences': 'ENSC', 'Environmental Toxicology': 'ENTX', 'Ethnic Studies': 'ETST', 'European Culture': 'EUR', 'Evoltn, Ecolgy, &amp; Orgnsml Bio': 'EEOB', 'Filipino': 'FIL', 'French': 'FREN', 'Gender and Sexuality Studies': 'GSST', 'Genetics': 'GEN', 'Geosciences': 'GEO', 'German': 'GER', 'Global Studies': 'GBST', 'Graduate Division': 'GDIV', 'Greek': 'GRK', 'History': 'HIST', 'History of Europe': 'HISE', 'History of the Americas': 'HISA', 'Honors': 'HNPG', 'Humanities, Arts and Soc Sci': 'HASS', 'Italian': 'ITAL', 'Japanese': 'JPN', 'Korean': 'KOR', 'Labor Relations': 'LABR', 'Latin': 'LATN', 'Latin American Studies': 'LNST', 'Law &amp; Society': 'LWSO', 'Lesbian, Gay, Bisexual Studies': 'LGBS', 'Linguistics': 'LING', 'Low Res-Crwt Wrt&amp;Wrt-Perf Arts': 'CWLR', 'Management': 'MGT', 'Materials Sci and Engineering': 'MSE', 'Mathematics': 'MATH', 'Mechanical Engineering': 'ME', 'Media and Cultural Studies': 'MCS', 'Microbiology': 'MCBL', 'Music': 'MUS', 'Natural &amp;Agricultural Sciences': 'NASC', 'Nematology': 'NEM', 'Neuroscience': 'NRSC', 'Peace and Conflict Studies': 'PCST', 'Philosophy': 'PHIL', 'Physics': 'PHYS', 'Plant Pathology': 'PLPA', 'Political Science': 'POSC', 'Portuguese': 'PORT', 'Psychology': 'PSYC', 'Public Policy': 'PBPL', 'Religious Studies': 'RLST', 'Russian Studies': 'RUSN', 'School of Medicine': 'MDCL', 'Sociology': 'SOC', 'Soil and Water Science': 'SWSC', 'Southeast Asian Studies': 'SEAS', 'Spanish': 'SPN', 'Statistics': 'STAT', 'Theater, Film &amp; Digital Prod': 'TFDP', 'Urban Studies': 'URST', 'Vietnamese': 'VNM'}
