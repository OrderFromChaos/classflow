# %%
### LIBRARIES / HEADER STUFF {
import json
from graphviz import Digraph
### }

# %%
### Hyperparams {
remove_grad_classes = True
color_requirements = False
required = {'PHYS039','MATH009A','MATH009B','MATH009C','CHEM001A',
                'CHEM001B','CHEM001C','CS010','MATH010A','MATH010B','MATH046',
                'PHYS041A','PHYS041B','PHYS041C','PHYS130A','PHYS130B','PHYS132',
                'PHYS135A','PHYS135B','PHYS156A','PHYS156B','PHYS139L','PHYS142W'}
draw_boxes = False
annotate_labels = False
### }

# %%
### IMPORT FROM DATASET {

# Opens and autocloses the file, binds file to f, and loads the data
with open('/home/order/Dropbox/Python_Code/Cloned/ucr-course-graph/data/201740_all_prereqs.json','r') as f:
    data = json.load(f)

# Define course object
class course:
    def __init__(self, courseName, preReq, courseID, subject):
        self.courseName = courseName
        self.preReq = preReq
        self.courseID = courseID
        self.subject = subject

# Mildly brittle parser
def parseAndOr(testString):
    if testString == dict():
        return dict()
    if len(testString.split('\n')) < 3:
        return dict()
    if 'Score for' in testString: # EXTREMELY HACKY SOLUTION
        return dict()
    mod = testString.split('and\n')
    mod = [x.split('or\n') for x in mod]
    mod = [[y.split('\n') for y in x] for x in mod]
    # mod = [[[z for z in y] for y in x] for x in mod]
    def classconvert(classname):
        intermed = classname.split(' ')
        intermed = [' '.join(intermed[:-1]), intermed[-1]]
        lookup = {
            'Computer Science':'CS',
            'Physics':'PHYS',
            'Mathematics':'MATH',
            'Electrical Engineering':'EE'
        }
        if intermed[0] in lookup:
            return lookup[intermed[0]] + intermed[1]
        else:
            return classname
    
    try:
        # This is the most horrific list comprehension I've every written, but it works
        mod = [[[
             classconvert(y[1][y[1].index('Test:')+6:].strip()), # Class name
             y[2].split(' ')[-1], # Grade
             'NC' if y[3].strip()[:7] == 'May not' else 'C' # Concurrent allowed?
                ] if y[0] == '(' else [
             classconvert(y[0][y[0].index('Test:')+6:].strip()), # Class name
             y[1].split(' ')[-1], # Grade
             'NC' if y[2].strip()[:7] == 'May not' else 'C' # Concurrent allowed?
                ] for y in x] for x in mod]
    except:
        print(testString)
        print(mod)
        raise
    return mod

courseList = []
for currentCourse in data:
    try: # Dealing with situations where prereq didn't get written
        mycourse = course(currentCourse['subjectCourse'], parseAndOr(currentCourse['prereqs']), currentCourse['id'], currentCourse['subject'])
    except KeyError:
        mycourse = course(currentCourse['subjectCourse'], dict(), currentCourse['id'], currentCourse['subject'])
    courseList.append(mycourse) # Writes course objects to a list

for i in courseList:
    if i != dict():
        print(i.preReq)

### }
# Out:
#     {}
#     {}
#     {}
#     {}
#     [[['Anthropology 001', 'D-', 'NC'], ['Anthropology 001H', 'D-', 'NC'], ['Anthropology 001W', 'D-', 'NC']]]
#     [[['Anthropology 003', 'D-', 'NC'], ['Anthropology 005', 'D-', 'NC']]]
#     [[['Anthropology 003', 'D-', 'NC'], ['Anthropology 005', 'D-', 'NC']]]
#     [[['Anthropology 001', 'D-', 'NC'], ['Anthropology 001H', 'D-', 'NC'], ['Anthropology 001W', 'D-', 'NC']], [['Linguistics 020', 'D-', 'NC']]]
#     [[['Anthropology 001', 'D-', 'NC'], ['Anthropology 001H', 'D-', 'NC'], ['Anthropology 001W', 'D-', 'NC']]]
#     [[['Linguistics 020', 'D-', 'NC']]]
#     [[['Anthropology 001', 'D-', 'NC'], ['Anthropology 001H', 'D-', 'NC'], ['Anthropology 001W', 'D-', 'NC']]]
#     [[['Anthropology 002', 'D-', 'NC']]]
#     [[['Anthropology 002', 'D-', 'NC']]]
#     {}
#     [[['Anthropology 001', 'D-', 'NC'], ['Anthropology 001H', 'D-', 'NC'], ['Anthropology 001W', 'D-', 'NC']]]
#     {}
#     [[['Arabic Language 003', 'C-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Art 001', 'D-', 'NC']], [['Art 002', 'D-', 'NC']]]
#     [[['Art 001', 'D-', 'NC']], [['Art 002', 'D-', 'NC']]]
#     [[['Art 003', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Chemistry 008A', 'C-', 'C']], [['Chemistry 08LA', 'C-', 'C'], ['Chemistry 08HA', 'C-', 'C']], [['Chemistry 08HLA', 'C-', 'C'], ['Chemistry 12A', 'C-', 'NC'], ['Chemistry 12HA', 'C-', 'NC']]]
#     [[['Biology 005A', 'C-', 'NC']], [['Chemistry 008C', 'C-', 'C']], [['Chemistry 08LC', 'C-', 'C'], ['Chemistry 08HC', 'C-', 'C']], [['Chemistry 08HLC', 'C-', 'C'], ['Chemistry 12C', 'C-', 'C'], ['Chemistry 12HC', 'C-', 'C']]]
#     [[['Psychology 001', 'C-', 'NC']]]
#     [[['Cell Biology and Neuroscience 120', 'D-', 'C'], ['Psychology 120', 'D-', 'C']]]
#     [[['Cell Biology and Neuroscience 106', 'D-', 'NC']]]
#     [[['Cell Biology and Neuroscience 106', 'C-', 'NC']]]
#     [[['Psychology 001', 'C-', 'NC']], [['Psychology 002', 'C-', 'NC']], [['Psychology 011', 'C-', 'NC']], [['Psychology 012', 'C-', 'NC']]]
#     [[['Psychology 002', 'D-', 'NC']]]
#     [[['Psychology 001', 'C-', 'NC']], [['Psychology 002', 'C-', 'NC']], [['Psychology 011', 'C-', 'NC']], [['Psychology 012', 'C-', 'NC']]]
#     [[['Psychology 001', 'C-', 'NC']], [['Psychology 002', 'C-', 'NC']], [['Psychology 011', 'C-', 'NC']], [['Psychology 012', 'C-', 'NC']]]
#     [[['Psychology 001', 'C-', 'NC']], [['Psychology 002', 'C-', 'NC']], [['Psychology 011', 'C-', 'NC']], [['Psychology 012', 'C-', 'NC']]]
#     [[['Psychology 001', 'C-', 'NC']], [['Psychology 002', 'C-', 'NC']], [['Psychology 011', 'C-', 'NC']], [['Psychology 012', 'C-', 'NC']], [['Psychology 160', 'D-', 'NC']]]
#     [[['Psychology 001', 'C-', 'NC']], [['Psychology 002', 'C-', 'NC'], ['Law & Society 100', 'C-', 'NC']]]
#     [[['Psychology 001', 'C-', 'NC']], [['Psychology 002', 'C-', 'NC']], [['Psychology 011', 'C-', 'NC']], [['Psychology 012', 'C-', 'NC']], [['Psychology 134', 'C-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Economics 003', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Russian Studies 003', 'C-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Sociology 001', 'D-', 'NC'], ['Sociology 001H', 'D-', 'NC']]]
#     [[['English 001B', 'C', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     [[['Political Science 010', 'D-', 'NC'], ['Political Science 010H', 'D-', 'NC'], ['Political Science 010W', 'D-', 'NC']]]
#     {}
#     {}
#     [[['Political Science 020', 'D-', 'NC']]]
#     {}
#     [[['Political Science 020', 'D-', 'NC'], ['Political Science 020H', 'D-', 'NC']]]
#     {}
#     [[['Political Science 010', 'D-', 'NC'], ['Political Science 010H', 'D-', 'NC'], ['Political Science 010W', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Political Science 201', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['English 001B', 'C', 'NC']], [['Psychology 001', 'C-', 'NC']], [['Psychology 002', 'C-', 'NC']], [['Psychology 011', 'C-', 'NC']]]
#     [[['English 001A', 'C-', 'NC']]]
#     {}
#     {}
#     {}
#     [[['MATH007A', 'D-', 'NC'], ['MATH008B', 'D-', 'NC'], ['MATH009A', 'D-', 'NC'], ['MATH09HA', 'D-', 'NC']], [['CS010', 'D-', 'NC'], ['CS010V', 'D-', 'NC'], ['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']]]
#     [[['CS010', 'C', 'NC'], ['CS010V', 'C', 'NC']]]
#     [[['CS012', 'C', 'NC'], ['CS012V', 'C', 'NC']]]
#     [[['CS010', 'C', 'NC'], ['CS010V', 'C', 'NC']]]
#     [[['CS014', 'C-', 'NC']]]
#     [[['CS010', 'D-', 'NC']], [['CS011', 'D-', 'NC'], ['MATH011', 'D-', 'NC']], [['MATH009C', 'D-', 'NC'], ['MATH09HC', 'D-', 'NC']]]
#     [[['CS061', 'C-', 'NC']]]
#     [[['CS012', 'D-', 'NC'], ['CS013', 'D-', 'NC']], [['CS120B', 'D-', 'NC'], ['EE120B', 'D-', 'NC']]]
#     [[['CS100', 'D-', 'NC']], [['MATH031', 'D-', 'C']]]
#     [[['CS014', 'C-', 'NC']], [['CS111', 'D-', 'NC']], [['MATH009C', 'D-', 'NC'], ['MATH09HC', 'D-', 'NC']]]
#     [[['CS061', 'D-', 'NC']], [['CS100', 'D-', 'NC']], [['CS111', 'D-', 'NC']]]
#     [[['EE120A', 'D-', 'NC'], ['CS120A', 'D-', 'NC']]]
#     [[['EE120A', 'D-', 'NC'], ['CS120A', 'D-', 'NC']], [['CS161', 'D-', 'C']]]
#     [[['CS100', 'D-', 'NC']], [['CS111', 'D-', 'NC']], [['CS153', 'D-', 'NC']]]
#     [[['CS141', 'D-', 'NC']], [['CS153', 'D-', 'NC']]]
#     [[['CS100', 'D-', 'NC']], [['CS111', 'D-', 'NC']]]
#     [[['CS100', 'C-', 'NC']], [['CS111', 'D-', 'NC']]]
#     [[['CS100', 'D-', 'NC']], [['MATH010A', 'D-', 'NC'], ['MATH031', 'D-', 'NC']]]
#     [[['CS100', 'D-', 'NC']]]
#     [[['CS153', 'D-', 'NC']]]
#     [[['CS161', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['CS141', 'D-', 'NC']], [['CS166', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Dance 014', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']]]
#     [[['Geosciences 001', 'D-', 'C']], [['MATH004', 'D-', 'NC'], ['MATH005', 'D-', 'NC'], ['MATH008A', 'D-', 'NC']]]
#     [[['Chemistry 001B', 'D-', 'C'], ['Chemistry 01HB', 'D-', 'C']], [['Chemistry 01LB', 'D-', 'C'], ['Chemistry 1HLB', 'D-', 'C']], [['Geosciences 001', 'C-', 'NC']]]
#     [[['Geosciences 001', 'C-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC'], ['PHYS040C', 'D-', 'NC']]]
#     [[['Biology 005C', 'D-', 'NC'], ['Biology 010', 'C-', 'NC'], ['Geosciences 003', 'C-', 'NC']]]
#     {}
#     [[['German 002', 'C-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     [[['Greek 003', 'C-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Ethnic Studies 001', 'D-', 'NC'], ['Ethnic Studies 001H', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     [[['Ethnic Studies 007', 'D-', 'NC'], ['Ethnic Studies 007H', 'D-', 'NC']]]
#     [[['Ethnic Studies 001', 'D-', 'NC'], ['Gender and Sexuality Studies 010', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     [[['Biology 105', 'D-', 'NC']]]
#     {}
#     {}
#     [[['Filipino 003', 'C-', 'NC']]]
#     {}
#     [[['French 001', 'C-', 'NC']]]
#     [[['French 002', 'C-', 'NC']]]
#     [[['French 003', 'C-', 'NC']]]
#     [[['French 004', 'C', 'NC']]]
#     [[['French 015B', 'C', 'NC']]]
#     [[['French 101A', 'C', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Economics 003', 'D-', 'NC']]]
#     {}
#     {}
#     [[['Ethnic Studies 001', 'D-', 'NC'], ['Gender and Sexuality Studies 010', 'D-', 'NC']]]
#     [[['Gender and Sexuality Studies 001', 'D-', 'NC'], ['Gender and Sexuality Studies 001H', 'D-', 'NC'], ['Gender and Sexuality Studies 001S', 'D-', 'NC']], [['Gender and Sexuality Studies 020', 'D-', 'NC'], ['Gender and Sexuality Studies 020H', 'D-', 'NC'], ['Gender and Sexuality Studies 020S', 'D-', 'NC'], ['Gender and Sexuality Studies 021', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']]]
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC'], ['Biology 100', 'D-', 'NC'], ['Entomology 100', 'D-', 'NC']]]
#     [[['Biochemistry 100', 'D-', 'C'], ['Biochemistry 110A', 'D-', 'C']]]
#     [[['Biology 127', 'D-', 'NC'], ['Entomology 127', 'D-', 'NC']]]
#     {}
#     [[['Chemical Engineering 120', 'D-', 'NC']], [['Environmental Engineering 142', 'D-', 'NC']]]
#     [[['Environmental Engineering 120', 'D-', 'NC']], [['Environmental Engineering 142', 'D-', 'NC']]]
#     [[['Chemistry 001C', 'D-', 'NC']], [['MATH009C', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
#     {}
#     {}
#     [[['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 01LC', 'D-', 'NC'], ['Chemistry 1HLC', 'D-', 'NC']], [['Environmental Sciences 002', 'D-', 'NC'], ['Environmental Sciences 002H', 'D-', 'NC'], ['Chemical and Environmental Eng 010', 'D-', 'NC']]]
#     [[['Chemistry 008A', 'D-', 'NC']], [['Chemistry 08LA', 'D-', 'NC'], ['Chemistry 08HA', 'D-', 'NC']], [['Chemistry 08HLA', 'D-', 'NC'], ['Chemistry 12HA', 'D-', 'NC'], ['Chemistry 12A', 'D-', 'NC']], [['Chemistry 008B', 'D-', 'NC']], [['Chemistry 08LB', 'D-', 'NC'], ['Chemistry 08HB', 'D-', 'NC']], [['Chemistry 08HLB', 'D-', 'NC'], ['Chemistry 12B', 'D-', 'NC'], ['Chemistry 12HB', 'D-', 'NC']]]
#     [[['Chemistry 005', 'C-', 'NC'], ['Environmental Sciences 101', 'C-', 'NC']]]
#     [[['Environmental Sciences 100', 'D-', 'NC']], [['Environmental Sciences 101', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['Statistics 100B', 'D-', 'NC']]]
#     [[['Environmental Sciences 006', 'D-', 'NC'], ['Economics 006', 'D-', 'NC'], ['Environmental Sciences 143A', 'D-', 'NC'], ['Economics 143A', 'D-', 'NC']], [['Environmental Sciences 100', 'D-', 'NC'], ['Environmental Sciences 101', 'D-', 'NC'], ['Environmental Sciences 102', 'D-', 'NC']]]
#     [[['Chemistry 001C', 'D-', 'NC']], [['Chemistry 01LC', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 1HLC', 'D-', 'NC']]]
#     [[['Chemistry 008A', 'D-', 'NC']], [['Chemistry 08LA', 'D-', 'NC'], ['Chemistry 08HA', 'D-', 'NC']], [['Chemistry 08HLA', 'D-', 'NC'], ['Chemistry 12HA', 'D-', 'NC'], ['Chemistry 12A', 'D-', 'NC']], [['Chemistry 008B', 'D-', 'NC']], [['Chemistry 08LB', 'D-', 'NC'], ['Chemistry 08HB', 'D-', 'NC']], [['Chemistry 08HLB', 'D-', 'NC'], ['Chemistry 12B', 'D-', 'NC'], ['Chemistry 12HB', 'D-', 'NC']]]
#     [[['Biochemistry 110A', 'D-', 'NC']], [['Biochemistry 110B', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     [[['MATH006A', 'C-', 'NC']]]
#     {}
#     {}
#     {}
#     [[['MATH007A', 'C-', 'NC'], ['MATH008B', 'C-', 'NC'], ['MATH009A', 'C-', 'NC'], ['MATH09HA', 'C-', 'NC']]]
#     [[['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']]]
#     [[['MATH007B', 'C-', 'NC'], ['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']]]
#     [[['MATH010A', 'C-', 'NC']]]
#     [[['MATH007A', 'D-', 'NC'], ['MATH008B', 'D-', 'NC'], ['MATH009A', 'D-', 'NC'], ['MATH09HA', 'D-', 'NC']], [['CS010', 'D-', 'NC'], ['CS010V', 'D-', 'NC'], ['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']]]
#     {}
#     [[['MATH007A', 'C-', 'NC'], ['MATH008B', 'C-', 'NC'], ['MATH009A', 'C-', 'NC'], ['MATH09HA', 'C-', 'NC']], [['CS010', 'C-', 'NC'], ['MATH007B', 'C-', 'NC'], ['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']]]
#     [[['MATH007B', 'C-', 'NC'], ['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']]]
#     {}
#     [[['MATH010A', 'C-', 'NC']], [['MATH031', 'C-', 'NC']]]
#     [[['MATH010A', 'C-', 'C']], [['MATH031', 'C-', 'NC']]]
#     [[['MATH031', 'C-', 'NC']]]
#     [[['CS010', 'C-', 'NC']], [['MATH031', 'C-', 'C']]]
#     [[['MATH010A', 'C-', 'NC']]]
#     [[['MATH009C', 'C-', 'NC'], ['MATH09HC', 'C-', 'NC']], [['MATH010A', 'C-', 'NC']], [['MATH031', 'C-', 'C']], [['MATH046', 'C-', 'NC']]]
#     [[['MATH010A', 'C-', 'NC']], [['MATH010B', 'C-', 'NC']], [['MATH046', 'C-', 'C']]]
#     [[['MATH010B', 'C-', 'NC']], [['MATH046', 'C-', 'NC']], [['MATH145A', 'C-', 'NC']]]
#     [[['MATH146A', 'D-', 'NC']]]
#     [[['MATH171', 'D-', 'NC']], [['MATH172', 'D-', 'NC']]]
#     [[['MATH145B', 'D-', 'NC']]]
#     [[['MATH146B', 'D-', 'NC']], [['MATH151B', 'D-', 'NC']]]
#     [[['MATH151C', 'D-', 'NC']]]
#     [[['MATH151C', 'D-', 'NC']], [['MATH165A', 'D-', 'NC']]]
#     [[['MATH209C', 'D-', 'NC']]]
#     [[['MATH201C', 'D-', 'NC']]]
#     [[['MATH201B', 'D-', 'NC']], [['MATH232B', 'D-', 'NC']]]
#     [[['MATH131', 'D-', 'NC']], [['MATH151C', 'D-', 'NC']]]
#     [[['MATH205A', 'D-', 'NC']], [['MATH205B', 'D-', 'NC']], [['MATH205C', 'D-', 'NC'], ['PHYS205', 'D-', 'NC']]]
#     {}
#     [[['Mechanical Engineering 002', 'D-', 'NC']]]
#     [[['MATH010A', 'D-', 'NC']], [['Mechanical Engineering 018', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
#     [[['MATH046', 'D-', 'NC']], [['Mechanical Engineering 010', 'C-', 'NC']], [['Mechanical Engineering 018', 'D-', 'NC']]]
#     [[['Chemistry 001B', 'D-', 'NC']], [['PHYS040C', 'D-', 'NC']]]
#     [[['Mechanical Engineering 116A', 'D-', 'NC']]]
#     [[['Mechanical Engineering 100A', 'D-', 'NC']], [['Mechanical Engineering 113', 'D-', 'NC']], [['Mechanical Engineering 116A', 'D-', 'NC']]]
#     [[['Bioengineering 105', 'D-', 'NC'], ['Mechanical Engineering 113', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
#     [[['Mechanical Engineering 120', 'D-', 'NC']], [['Mechanical Engineering 121', 'D-', 'NC']]]
#     [[['Mechanical Engineering 110', 'D-', 'NC']], [['Mechanical Engineering 114', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['CS011', 'D-', 'NC'], ['MATH011', 'D-', 'NC'], ['CS120A', 'D-', 'NC'], ['EE120A', 'D-', 'NC'], ['CS150', 'D-', 'NC'], ['Philosophy 008', 'D-', 'NC'], ['Philosophy 008H', 'D-', 'NC']]]
#     {}
#     [[['Philosophy 001', 'D-', 'NC'], ['Philosophy 001H', 'D-', 'NC'], ['Philosophy 002', 'D-', 'NC'], ['Philosophy 002H', 'D-', 'NC'], ['Philosophy 003', 'D-', 'NC'], ['Philosophy 003H', 'D-', 'NC'], ['Philosophy 003W', 'D-', 'NC'], ['Philosophy 003X', 'D-', 'NC'], ['Philosophy 004', 'D-', 'NC'], ['Philosophy 005', 'D-', 'NC'], ['Philosophy 006', 'D-', 'NC'], ['Philosophy 007', 'D-', 'NC'], ['Philosophy 007H', 'D-', 'NC'], ['Philosophy 008', 'D-', 'NC'], ['Philosophy 008H', 'D-', 'NC'], ['Philosophy 009', 'D-', 'NC'], ['Philosophy 009H', 'D-', 'NC'], ['Philosophy 010', 'D-', 'NC'], ['Philosophy 010H', 'D-', 'NC'], ['Philosophy 012', 'D-', 'NC'], ['Philosophy 030E', 'D-', 'NC'], ['Philosophy 030F', 'D-', 'NC'], ['Philosophy 030G', 'D-', 'NC'], ['Philosophy 030I', 'D-', 'NC'], ['Philosophy 030J', 'D-', 'NC'], ['Philosophy 030K', 'D-', 'NC'], ['Philosophy 030M', 'D-', 'NC'], ['Philosophy 030N', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     [[['MATH009A', 'C-', 'NC'], ['MATH09HA', 'C-', 'NC'], ['MATH008B', 'C-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     [[['MATH009A', 'D-', 'NC'], ['MATH09HA', 'D-', 'NC'], ['MATH022', 'D-', 'NC']]]
#     [[['Economics 002', 'D-', 'NC']]]
#     [[['Economics 003', 'C-', 'NC']], [['MATH009A', 'D-', 'NC'], ['MATH09HA', 'D-', 'NC']]]
#     [[['Economics 002', 'D-', 'NC']]]
#     [[['Economics 101', 'D-', 'NC']], [['Economics 002', 'D-', 'NC'], ['Economics 003', 'D-', 'NC']]]
#     [[['Economics 104B', 'D-', 'NC']], [['MATH010A', 'D-', 'NC']], [['MATH131', 'D-', 'NC']]]
#     {}
#     [[['Economics 002', 'D-', 'NC'], ['Economics 002H', 'D-', 'NC'], ['Economics 003', 'D-', 'NC'], ['Economics 004', 'D-', 'NC']]]
#     [[['Economics 002', 'D-', 'NC']], [['Economics 003', 'D-', 'NC']]]
#     [[['Economics 102', 'D-', 'NC'], ['Economics 104A', 'D-', 'NC']]]
#     [[['Business 020', 'D-', 'NC']], [['Economics 002', 'D-', 'NC']], [['Economics 003', 'D-', 'NC']], [['Economics 101', 'D-', 'NC'], ['Statistics 048', 'D-', 'NC']]]
#     [[['Economics 002', 'D-', 'NC']], [['Economics 003', 'D-', 'NC']]]
#     [[['Economics 102', 'D-', 'NC'], ['Economics 104A', 'D-', 'NC']]]
#     [[['Economics 003', 'D-', 'NC']]]
#     [[['Economics 102', 'D-', 'NC'], ['Economics 104A', 'D-', 'NC']]]
#     [[['Economics 101', 'D-', 'NC']], [['Economics 104B', 'D-', 'NC']]]
#     [[['Economics 102', 'D-', 'NC'], ['Economics 104A', 'D-', 'NC']]]
#     [[['Economics 102', 'D-', 'NC'], ['Economics 104A', 'D-', 'NC']], [['Economics 107', 'D-', 'NC']]]
#     [[['Economics 104B', 'D-', 'NC']]]
#     [[['Economics 105B', 'D-', 'NC']]]
#     [[['Economics 104A', 'D-', 'NC']], [['Economics 105A', 'D-', 'NC']], [['MATH009A', 'D-', 'NC']], [['MATH009B', 'D-', 'NC']], [['Statistics 100B', 'D-', 'NC']]]
#     [[['Economics 205B', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Education 241A', 'D-', 'NC']]]
#     [[['Education 215A', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['MATH046', 'D-', 'C']], [['PHYS040C', 'D-', 'C']]]
#     [[['EE001A', 'D-', 'NC']], [['EE01LA', 'D-', 'NC']]]
#     {}
#     [[['EE001B', 'D-', 'NC']]]
#     [[['EE020', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['EE001B', 'D-', 'C']]]
#     [[['EE110B', 'D-', 'NC']]]
#     [[['CS061', 'C-', 'NC']]]
#     [[['EE100B', 'D-', 'C']], [['CS120B', 'D-', 'C'], ['EE120B', 'D-', 'C']]]
#     [[['EE100A', 'D-', 'NC']]]
#     [[['PHYS040C', 'D-', 'NC']]]
#     [[['PHYS040C', 'D-', 'NC']]]
#     [[['EE110B', 'D-', 'NC']]]
#     [[['EE001B', 'D-', 'NC']], [['EE116', 'D-', 'NC']]]
#     [[['CS120B', 'D-', 'NC'], ['EE120B', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     [[['Business 020', 'C-', 'NC']]]
#     [[['English 001B', 'C', 'NC']]]
#     [[['CS008', 'D-', 'NC']]]
#     {}
#     {}
#     [[['CS008', 'D-', 'NC']], [['Statistics 048', 'D-', 'NC'], ['Statistics 100A', 'D-', 'NC']]]
#     [[['Business 104', 'D-', 'NC'], ['Statistics 104', 'D-', 'NC']]]
#     [[['Business 020', 'D-', 'NC']], [['Economics 002', 'D-', 'NC']], [['Economics 003', 'D-', 'NC']], [['Economics 101', 'D-', 'NC'], ['Statistics 048', 'D-', 'NC']]]
#     {}
#     [[['Business 020', 'D-', 'NC']]]
#     {}
#     [[['Business 103', 'D-', 'NC']]]
#     [[['Business 103', 'D-', 'NC']]]
#     [[['Business 103', 'D-', 'NC']]]
#     [[['Business 103', 'D-', 'NC']]]
#     [[['Business 103', 'D-', 'NC']]]
#     [[['Business 105', 'D-', 'NC']]]
#     [[['Business 106', 'C-', 'NC'], ['Economics 134', 'C-', 'NC']], [['Business 132', 'C-', 'NC']]]
#     [[['Business 020', 'D-', 'NC']], [['Economics 101', 'D-', 'NC'], ['Statistics 048', 'D-', 'NC']], [['Economics 102', 'D-', 'NC'], ['Economics 103', 'D-', 'NC'], ['Economics 104A', 'D-', 'NC'], ['Economics 105A', 'D-', 'NC']]]
#     [[['Business 106', 'C-', 'NC'], ['Economics 134', 'C-', 'NC']], [['Business 132', 'C-', 'NC']]]
#     [[['Business 106', 'D-', 'NC'], ['Economics 134', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     [[['Business 107', 'D-', 'NC']]]
#     {}
#     [[['Economics 102', 'D-', 'NC'], ['Economics 104A', 'D-', 'NC']]]
#     [[['Business 021', 'D-', 'NC']]]
#     [[['Business 165B', 'D-', 'NC']]]
#     [[['Business 101', 'D-', 'NC']], [['Business 108', 'D-', 'NC']]]
#     [[['Business 108', 'D-', 'NC']]]
#     [[['Business 165B', 'D-', 'NC']]]
#     [[['Business 101', 'D-', 'NC']]]
#     [[['Business 103', 'D-', 'NC']], [['Economics 003', 'D-', 'NC']]]
#     [[['Economics 102', 'D-', 'NC'], ['Economics 104A', 'D-', 'NC']]]
#     {}
#     {}
#     [[['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'C'], ['Biochemistry 110A', 'D-', 'C']]]
#     [[['Biology 005A', 'C-', 'NC']], [['Biology 005B', 'C-', 'NC']], [['Chemistry 001A', 'D-', 'NC'], ['Chemistry 01HA', 'D-', 'NC']], [['Chemistry 001B', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC']]]
#     [[['Cell Biology and Neuroscience 120', 'D-', 'C'], ['Psychology 120', 'D-', 'C']]]
#     [[['Cell Biology and Neuroscience 106', 'D-', 'NC']]]
#     [[['Cell Biology and Neuroscience 106', 'C-', 'NC']]]
#     [[['Biology 005C', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'NC'], ['Biochemistry 110A', 'D-', 'NC']]]
#     {}
#     [[['EE117', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['EE215', 'D-', 'NC']]]
#     {}
#     {}
#     [[['Chemistry 001A', 'D-', 'NC'], ['Chemistry 01HA', 'D-', 'NC']], [['CS010', 'D-', 'NC'], ['CS030', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
#     [[['MATH010A', 'D-', 'NC']], [['CS010', 'D-', 'NC'], ['EE020', 'D-', 'NC'], ['Mechanical Engineering 018', 'D-', 'NC']]]
#     [[['English 001B', 'C', 'NC']]]
#     {}
#     {}
#     [[['English 001A', 'C', 'NC'], ['English 01PA', 'C', 'NC']]]
#     [[['English 001B', 'C', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['English 001B', 'C', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Mechanical Engineering 009', 'D-', 'NC']]]
#     [[['Mechanical Engineering 175A', 'D-', 'C']], [['Mechanical Engineering 113', 'D-', 'NC']], [['Mechanical Engineering 116A', 'D-', 'NC']], [['Mechanical Engineering 170A', 'D-', 'NC']], [['Mechanical Engineering 174', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Mechanical Engineering 110', 'D-', 'NC']], [['Mechanical Engineering 114', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Art 003', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 05LA', 'D-', 'NC'], ['Biology 020', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'NC'], ['Biochemistry 110A', 'D-', 'NC']]]
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Biology 05LA', 'D-', 'NC'], ['Biology 020', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'C'], ['Biochemistry 110A', 'D-', 'C']]]
#     [[['Biochemistry 110C', 'D-', 'NC'], ['Biology 107A', 'D-', 'NC']], [['Biology 102', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Music 010', 'D-', 'NC']], [['Music 031A', 'D-', 'C']]]
#     [[['Music 001', 'D-', 'NC'], ['Music 010', 'D-', 'NC']]]
#     [[['Music 030A', 'D-', 'NC']], [['Music 030B', 'D-', 'NC']], [['Music 030C', 'D-', 'NC']]]
#     [[['Music 031C', 'D-', 'NC']]]
#     [[['Music 030A', 'D-', 'NC']], [['Music 030B', 'D-', 'NC']], [['Music 030C', 'D-', 'NC']]]
#     [[['Music 030A', 'D-', 'NC']], [['Music 030B', 'D-', 'NC']], [['Music 030C', 'D-', 'NC']]]
#     {}
#     [[['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']]]
#     [[['Biology 005A', 'C-', 'NC']], [['Biology 020', 'C-', 'NC'], ['Biology 05LA', 'C-', 'NC']], [['Biology 005B', 'C-', 'NC']]]
#     [[['Biology 005C', 'D-', 'NC']]]
#     [[['Biology 005C', 'C-', 'NC']], [['Biology 102', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'NC'], ['Biochemistry 110A', 'D-', 'NC']]]
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC']], [['MATH09HB', 'D-', 'NC'], ['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'NC'], ['Biochemistry 110A', 'D-', 'NC']]]
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']]]
#     [[['Biology 005C', 'C-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']]]
#     [[['Biology 005C', 'C-', 'NC']], [['Biology 102', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'NC'], ['Biochemistry 110A', 'D-', 'NC']]]
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 05LA', 'D-', 'NC'], ['Biology 020', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'NC'], ['Biochemistry 110A', 'D-', 'NC']]]
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Biology 05LA', 'D-', 'NC'], ['Biology 020', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'C'], ['Biochemistry 110A', 'D-', 'C']]]
#     [[['Biochemistry 100', 'D-', 'NC'], ['Biochemistry 110A', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']]]
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Biology 05LA', 'D-', 'NC'], ['Biology 020', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'NC'], ['Biochemistry 110A', 'D-', 'NC']]]
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'C'], ['Biochemistry 110A', 'D-', 'C']], [['Biology 104', 'D-', 'NC'], ['Botany/Plant Science 104', 'D-', 'NC']]]
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'NC'], ['Biochemistry 110A', 'D-', 'NC']]]
#     [[['Biology 005A', 'C-', 'NC']], [['Biology 005B', 'C-', 'NC']], [['Biology 005C', 'C-', 'NC']], [['Chemistry 001C', 'C-', 'NC'], ['Chemistry 01HC', 'C-', 'NC']], [['Chemistry 008A', 'C-', 'NC']], [['Chemistry 08LA', 'C-', 'NC'], ['Chemistry 08HA', 'C-', 'NC']], [['Chemistry 08HLA', 'C-', 'NC'], ['Chemistry 12HA', 'C-', 'NC'], ['Chemistry 12A', 'C-', 'NC']], [['MATH007B', 'C-', 'NC'], ['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']], [['PHYS002A', 'C-', 'NC']]]
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC'], ['Biology 100', 'D-', 'NC'], ['Entomology 100', 'D-', 'NC']]]
#     [[['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['MATH09HB', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC']]]
#     [[['Biochemistry 110A', 'D-', 'C'], ['Biochemistry 110B', 'D-', 'C']], [['Biology 102', 'D-', 'NC']], [['Biology 107A', 'D-', 'NC']]]
#     [[['Biochemistry 110C', 'D-', 'NC'], ['Biology 107A', 'D-', 'NC']], [['Biology 102', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Biomedical Sciences 232', 'D-', 'C']]]
#     {}
#     [[['Biology 005C', 'D-', 'NC']]]
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'C'], ['Biochemistry 110A', 'D-', 'C']], [['Biology 104', 'D-', 'NC'], ['Botany/Plant Science 104', 'D-', 'NC']]]
#     [[['Biology 104', 'D-', 'NC'], ['Botany/Plant Science 104', 'D-', 'NC'], ['Biology 116', 'D-', 'NC']], [['Statistics 100A', 'D-', 'NC']]]
#     [[['Biochemistry 110A', 'D-', 'NC']], [['Biochemistry 110B', 'D-', 'NC'], ['Biochemistry 100', 'D-', 'NC']]]
#     {}
#     [[['Biology 107A', 'D-', 'NC'], ['Biology 143', 'D-', 'NC'], ['Botany/Plant Science 143', 'D-', 'NC'], ['Biochemistry 100', 'D-', 'NC'], ['Cell Biology and Neuroscience 101', 'D-', 'NC']]]
#     [[['MATH009C', 'D-', 'NC'], ['MATH09HC', 'D-', 'NC']], [['Statistics 110', 'D-', 'NC'], ['Statistics 231A', 'D-', 'NC']]]
#     [[['Chemistry 001C', 'B', 'NC']], [['Chemistry 01LC', 'B', 'NC'], ['Chemistry 01HC', 'B', 'NC']], [['Chemistry 1HLC', 'B', 'NC']]]
#     [[['Chemistry 001C', 'C-', 'NC'], ['Chemistry 01HC', 'C-', 'NC']], [['Chemistry 01LC', 'C-', 'NC'], ['Chemistry 1HLC', 'C-', 'NC']], [['MATH009B', 'C-', 'NC'], ['MATH09HB', 'C-', 'NC']]]
#     [[['Chemistry 001C', 'C-', 'NC'], ['Chemistry 01HC', 'C-', 'NC']], [['Chemistry 01LC', 'C-', 'NC'], ['Chemistry 1HLC', 'C-', 'NC']], [['MATH010A', 'C-', 'C'], ['MATH009A', 'C-', 'NC'], ['MATH09HC', 'C-', 'NC']], [['PHYS002C', 'C-', 'NC'], ['PHYS040C', 'C-', 'C']]]
#     [[['Chemistry 005', 'C-', 'NC']], [['PHYS002C', 'D-', 'C'], ['PHYS040C', 'D-', 'C']]]
#     [[['Chemistry 008A', 'D-', 'NC']], [['Chemistry 08LA', 'D-', 'NC'], ['Chemistry 08HA', 'D-', 'NC']], [['Chemistry 08HLA', 'D-', 'NC'], ['Chemistry 12HA', 'D-', 'NC'], ['Chemistry 12A', 'D-', 'NC']], [['Chemistry 008B', 'D-', 'NC']], [['Chemistry 08LB', 'D-', 'NC'], ['Chemistry 08HB', 'D-', 'NC']], [['Chemistry 08HLB', 'D-', 'NC'], ['Chemistry 12HB', 'D-', 'NC'], ['Chemistry 12B', 'D-', 'NC']]]
#     [[['Chemistry 005', 'C-', 'NC'], ['Environmental Sciences 104', 'C-', 'NC']]]
#     [[['Chemistry 113', 'C', 'NC']]]
#     [[['Chemistry 110A', 'C', 'NC']], [['Chemistry 110B', 'C', 'NC']]]
#     {}
#     {}
#     [[['Chemistry 125', 'D-', 'NC']]]
#     [[['Chemistry 125', 'D-', 'NC']]]
#     [[['Chemistry 150A', 'D-', 'NC']], [['Chemistry 150B', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     [[['Chinese 002', 'C-', 'NC']]]
#     [[['Chinese 003', 'C-', 'NC']]]
#     {}
#     [[['Chinese 002', 'C-', 'NC'], ['Chinese 020A', 'C-', 'NC']]]
#     [[['Chinese 006', 'D-', 'NC'], ['Chinese 025', 'D-', 'NC']]]
#     [[['Chinese 102', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Biology 005A', 'C-', 'NC']], [['Chemistry 008C', 'C-', 'NC']], [['Chemistry 08LC', 'C-', 'NC'], ['Chemistry 08HC', 'C-', 'NC']], [['Chemistry 08HLC', 'C-', 'NC'], ['Chemistry 12HC', 'C-', 'NC'], ['Chemistry 12C', 'C-', 'NC']]]
#     [[['Biochemistry 100', 'C-', 'NC'], ['Biochemistry 110B', 'C-', 'NC']], [['Biology 102', 'D-', 'NC']]]
#     [[['Biochemistry 110A', 'D-', 'NC']], [['Biochemistry 110B', 'D-', 'NC'], ['Biochemistry 100', 'D-', 'NC']]]
#     [[['Biochemistry 110A', 'D-', 'NC']], [['Biochemistry 110B', 'D-', 'NC']], [['Biochemistry 110C', 'D-', 'NC']], [['Biochemistry 184', 'D-', 'NC']], [['Chemistry 109', 'D-', 'NC']]]
#     {}
#     {}
#     [[['Biology 005A', 'D-', 'NC']], [['Chemistry 008A', 'D-', 'NC']], [['Chemistry 08LA', 'D-', 'NC'], ['Chemistry 08HA', 'D-', 'NC']], [['Chemistry 08HLA', 'D-', 'NC'], ['Chemistry 12A', 'D-', 'NC'], ['Chemistry 12HA', 'D-', 'NC']], [['MATH046', 'D-', 'NC']]]
#     [[['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['CS010', 'D-', 'NC']], [['MATH010A', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
#     [[['Bioengineering 101', 'D-', 'NC']], [['MATH010B', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['PHYS040C', 'D-', 'NC']]]
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']]]
#     [[['Bioengineering 105', 'D-', 'NC']], [['Biology 002', 'D-', 'NC'], ['Biology 005A', 'D-', 'NC']]]
#     {}
#     [[['Bioengineering 155', 'C-', 'C']], [['Bioengineering 010', 'C-', 'NC']], [['Bioengineering 130L', 'C-', 'NC']]]
#     {}
#     {}
#     [[['Bioengineering 110', 'D-', 'NC']], [['Bioengineering 140A', 'D-', 'NC']], [['Biology 005A', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']]]
#     {}
#     {}
#     [[['Chemistry 001A', 'C-', 'NC']], [['Chemistry 01LA', 'C-', 'NC'], ['Chemistry 01HA', 'C-', 'NC']], [['Chemistry 1HLA', 'C-', 'NC']]]
#     [[['Biology 005A', 'C-', 'NC']], [['Biology 020', 'C-', 'NC'], ['Biology 05LA', 'C-', 'NC']], [['Chemistry 001A', 'D-', 'NC'], ['Chemistry 01HA', 'D-', 'NC']], [['Chemistry 001B', 'D-', 'NC'], ['Chemistry 01HB', 'D-', 'NC']]]
#     [[['Biology 005A', 'C-', 'NC']], [['Biology 020', 'C-', 'NC'], ['Biology 05LA', 'C-', 'NC']], [['Biology 005B', 'C-', 'NC']], [['MATH009A', 'C-', 'NC'], ['MATH09HA', 'C-', 'NC'], ['MATH008B', 'C-', 'NC']]]
#     {}
#     [[['English 001B', 'C', 'NC']]]
#     {}
#     {}
#     {}
#     [[['English 001B', 'C', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Italian 003', 'C-', 'NC'], ['Italian 020B', 'C-', 'NC']]]
#     {}
#     {}
#     {}
#     [[['Japanese 002', 'C-', 'NC']]]
#     [[['Japanese 003', 'C-', 'NC'], ['Japanese 010B', 'C-', 'NC']]]
#     {}
#     [[['Japanese 006', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     [[['Korean 003', 'C-', 'NC']]]
#     {}
#     {}
#     {}
#     [[['Latin 003', 'C-', 'NC']]]
#     {}
#     {}
#     [[['Spanish 110', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     [[['Linguistics 111', 'D-', 'NC']], [['Linguistics 121', 'D-', 'NC'], ['Linguistics 141', 'D-', 'NC']]]
#     [[['Linguistics 111', 'D-', 'NC']], [['Linguistics 121', 'D-', 'NC'], ['Linguistics 141', 'D-', 'NC']]]
#     {}
#     [[['Management 403', 'D-', 'NC']]]
#     [[['Management 201', 'D-', 'NC']], [['Management 211', 'D-', 'NC']]]
#     [[['Management 211', 'D-', 'NC']]]
#     {}
#     {}
#     [[['Management 207', 'D-', 'NC']]]
#     [[['Management 200', 'D-', 'NC']]]
#     [[['Management 209', 'D-', 'NC']]]
#     [[['Management 204', 'D-', 'NC']]]
#     [[['Management 202', 'D-', 'NC']]]
#     [[['Management 211', 'D-', 'NC']]]
#     [[['Management 204', 'D-', 'NC']]]
#     [[['Management 202', 'D-', 'NC'], ['Management 209', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Materials Sci and Engineering 160', 'D-', 'NC']]]
#     {}
#     {}
#     [[['Chemistry 110A', 'C', 'NC']], [['Chemistry 110B', 'C', 'NC']]]
#     [[['MATH046', 'D-', 'NC']], [['PHYS040A', 'D-', 'NC']]]
#     {}
#     [[['PHYS221C', 'D-', 'NC']]]
#     [[['Mechanical Engineering 110', 'D-', 'NC']], [['Mechanical Engineering 114', 'D-', 'NC']]]
#     [[['Chemistry 150A', 'D-', 'NC']], [['Chemistry 150B', 'D-', 'NC']]]
#     {}
#     [[['Biochemistry 110A', 'D-', 'C'], ['Biochemistry 110B', 'D-', 'C']], [['Biology 102', 'D-', 'NC']], [['Biology 107A', 'D-', 'NC']]]
#     [[['Biology 102', 'D-', 'NC']]]
#     {}
#     [[['Chemistry 001C', 'D-', 'NC']], [['MATH046', 'D-', 'C']], [['PHYS040B', 'D-', 'NC']]]
#     [[['Chemistry 001C', 'D-', 'NC']], [['MATH009C', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
#     [[['Chemical Engineering 110A', 'D-', 'NC'], ['Environmental Engineering 171', 'D-', 'NC']], [['MATH010A', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['PHYS040B', 'D-', 'NC']]]
#     [[['Chemical Engineering 116', 'D-', 'NC']], [['Chemical Engineering 120', 'D-', 'NC']]]
#     [[['Biology 121', 'D-', 'C'], ['Microbiology 121', 'D-', 'C']], [['Biochemistry 110A', 'D-', 'NC']], [['Chemical Engineering 120', 'D-', 'NC']], [['Chemical Engineering 122', 'D-', 'NC']]]
#     {}
#     [[['Chemistry 008A', 'D-', 'NC']], [['Chemistry 08LA', 'D-', 'NC'], ['Chemistry 08HA', 'D-', 'NC']], [['Chemistry 08HLA', 'D-', 'NC'], ['Chemistry 12HA', 'D-', 'NC'], ['Chemistry 12A', 'D-', 'NC']], [['PHYS040C', 'D-', 'NC']]]
#     [[['Engineering 118', 'D-', 'NC']]]
#     [[['Chemical Engineering 130', 'D-', 'NC'], ['Environmental Engineering 130', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     [[['Chemistry 001B', 'C-', 'NC'], ['Chemistry 01HB', 'C-', 'NC']], [['Chemistry 01LB', 'C-', 'NC'], ['Chemistry 1HLB', 'C-', 'NC']]]
#     [[['MATH005', 'D-', 'C'], ['MATH006A', 'D-', 'C']]]
#     [[['Chemistry 001C', 'C-', 'NC']], [['Chemistry 01LC', 'C-', 'NC'], ['Chemistry 01HC', 'C-', 'NC']], [['Chemistry 1HLC', 'C-', 'NC']]]
#     [[['Chemistry 008B', 'C-', 'NC']], [['Chemistry 08LB', 'C-', 'NC'], ['Chemistry 08HB', 'C-', 'NC']], [['Chemistry 08HLB', 'C-', 'NC'], ['Chemistry 12B', 'C-', 'NC'], ['Chemistry 12HB', 'C-', 'NC']]]
#     {}
#     [[['Sociology 001', 'D-', 'NC'], ['Sociology 001H', 'D-', 'NC']]]
#     [[['Sociology 001', 'C-', 'NC'], ['Sociology 001H', 'C-', 'NC']]]
#     [[['Sociology 001', 'C-', 'NC'], ['Sociology 001H', 'C-', 'NC']]]
#     [[['Sociology 004', 'C-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     [[['Sociology 005', 'C-', 'NC']]]
#     [[['Sociology 001', 'D-', 'NC'], ['Sociology 001H', 'D-', 'NC']]]
#     [[['Sociology 001', 'D-', 'NC'], ['Sociology 001H', 'D-', 'NC']]]
#     [[['Sociology 005', 'C-', 'NC']]]
#     [[['Sociology 001', 'C', 'NC'], ['Sociology 001H', 'C', 'NC']], [['Sociology 004', 'C', 'NC']]]
#     [[['Sociology 001', 'D-', 'NC'], ['Sociology 001H', 'D-', 'NC']]]
#     [[['Sociology 003', 'C-', 'NC']], [['Sociology 005', 'C-', 'NC']]]
#     [[['Sociology 001', 'C', 'NC']], [['Sociology 004', 'C', 'NC']], [['Sociology 005', 'C', 'NC'], ['Sociology 001H', 'C', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     [[['Spanish 001', 'C-', 'NC']]]
#     [[['Spanish 002', 'C-', 'NC']]]
#     [[['Spanish 003', 'C-', 'NC']]]
#     [[['Spanish 004', 'D-', 'NC']]]
#     [[['Spanish 005', 'D-', 'NC']]]
#     [[['Spanish 006', 'D-', 'NC']]]
#     [[['Spanish 101B', 'D-', 'NC'], ['Spanish 109B', 'D-', 'NC']]]
#     [[['Linguistics 020', 'D-', 'NC']], [['Spanish 101A', 'D-', 'NC']], [['Spanish 101B', 'D-', 'NC'], ['Spanish 109A', 'D-', 'NC']], [['Spanish 109B', 'D-', 'NC']]]
#     {}
#     [[['Spanish 109A', 'D-', 'NC']]]
#     [[['Spanish 101A', 'D-', 'NC']], [['Spanish 101B', 'D-', 'NC'], ['Spanish 109A', 'D-', 'NC']], [['Spanish 109B', 'D-', 'NC']]]
#     [[['Spanish 110', 'D-', 'NC']]]
#     [[['Spanish 110', 'D-', 'NC']]]
#     [[['Spanish 110', 'D-', 'NC']]]
#     [[['Spanish 110', 'D-', 'NC']]]
#     [[['Spanish 110', 'D-', 'NC']]]
#     [[['CS008', 'D-', 'NC']], [['MATH004', 'D-', 'NC'], ['MATH005', 'D-', 'NC'], ['MATH006B', 'D-', 'NC'], ['MATH007A', 'D-', 'NC'], ['MATH009A', 'D-', 'NC'], ['MATH09HA', 'D-', 'NC']]]
#     [[['MATH005', 'D-', 'NC'], ['MATH006B', 'D-', 'NC'], ['MATH007A', 'D-', 'NC'], ['MATH009A', 'D-', 'NC'], ['MATH09HA', 'D-', 'NC']]]
#     [[['Statistics 100A', 'C-', 'NC']]]
#     [[['CS008', 'D-', 'NC']], [['Statistics 048', 'D-', 'NC'], ['Statistics 100A', 'D-', 'NC']]]
#     [[['Statistics 100B', 'D-', 'NC']]]
#     [[['Statistics 100B', 'D-', 'NC']]]
#     [[['Statistics 100A', 'D-', 'NC']]]
#     [[['MATH009C', 'D-', 'C'], ['MATH09HC', 'D-', 'C']]]
#     [[['MATH009C', 'D-', 'C'], ['MATH09HC', 'D-', 'C']]]
#     [[['Statistics 157', 'D-', 'NC']], [['Statistics 160C', 'D-', 'NC']]]
#     [[['MATH010B', 'D-', 'NC']], [['Statistics 160C', 'D-', 'NC']]]
#     [[['Statistics 170A', 'D-', 'NC']]]
#     [[['Statistics 160C', 'D-', 'NC']]]
#     [[['Statistics 201C', 'D-', 'NC']]]
#     [[['Statistics 100B', 'D-', 'NC']]]
#     [[['Statistics 160A', 'D-', 'NC']], [['Statistics 160B', 'D-', 'NC']], [['Statistics 160C', 'D-', 'NC']]]
#     [[['Statistics 160C', 'D-', 'NC']], [['Statistics 170B', 'D-', 'NC']], [['Statistics 171', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Theater, Film & Digital Prod 109', 'D', 'NC']]]
#     {}
#     {}
#     {}
#     {}
#     {}
#     [[['Creative Writing 066', 'D-', 'NC'], ['Media and Cultural Studies 066', 'D-', 'NC'], ['Theater, Film & Digital Prod 066', 'D-', 'NC']]]
#     [[['Creative Writing 066', 'D-', 'NC'], ['Media and Cultural Studies 066', 'D-', 'NC'], ['Theater, Film & Digital Prod 066', 'D-', 'NC']]]
#     {}
#     {}
#     [[['Vietnamese 003', 'C-', 'NC'], ['Vietnamese 020B', 'C-', 'NC']]]
#     [[['MATH009B', 'D-', 'C'], ['MATH09HB', 'D-', 'C']], [['PHYS002A', 'C-', 'NC']]]
#     {}
#     {}
#     {}
#     [[['MATH008B', 'C-', 'NC'], ['MATH009A', 'C-', 'NC'], ['MATH09HA', 'C-', 'NC']], [['MATH009B', 'D-', 'C'], ['MATH09HB', 'D-', 'C']]]
#     [[['PHYS040B', 'C-', 'NC']], [['MATH009C', 'D-', 'NC'], ['MATH09HC', 'D-', 'NC']]]
#     [[['MATH009A', 'C-', 'C'], ['MATH09HA', 'C-', 'C']]]
#     [[['MATH010B', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['PHYS040D', 'C-', 'NC'], ['PHYS041C', 'C-', 'NC'], ['PHYS002C', 'B-', 'NC']]]
#     [[['MATH009C', 'D-', 'NC']], [['MATH010A', 'D-', 'C']], [['PHYS002A', 'B-', 'NC'], ['PHYS040A', 'C-', 'NC'], ['PHYS041A', 'C-', 'NC']]]
#     [[['MATH010B', 'D-', 'NC']], [['MATH046', 'D-', 'NC']], [['PHYS002B', 'B-', 'NC'], ['PHYS040C', 'C-', 'NC'], ['PHYS041B', 'C-', 'NC']]]
#     [[['PHYS002B', 'B-', 'NC'], ['PHYS040C', 'C-', 'NC'], ['PHYS041B', 'C-', 'NC']]]
#     [[['PHYS002B', 'B-', 'NC'], ['PHYS040E', 'C-', 'NC'], ['PHYS041C', 'C-', 'NC']]]
#     [[['MATH010B', 'D-', 'NC']], [['MATH046', 'D-', 'C']], [['PHYS130B', 'D-', 'NC']], [['PHYS002C', 'B-', 'NC'], ['PHYS040E', 'C-', 'NC'], ['PHYS041C', 'C-', 'NC']]]
#     {}
#     [[['PHYS135B', 'D-', 'NC']], [['PHYS156A', 'D-', 'NC']]]
#     {}
#     {}
#     {}
#     [[['PHYS221A', 'D-', 'NC']], [['PHYS221B', 'D-', 'NC']], [['PHYS221C', 'D-', 'NC']]]
#     [[['PHYS221A', 'D-', 'NC']], [['PHYS221B', 'D-', 'NC']], [['PHYS221C', 'D-', 'NC']]]
#     {}
#     {}
#     [[['PHYS221C', 'D-', 'NC']]]
#     {}
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 05LA', 'D-', 'NC'], ['Biology 020', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'NC'], ['Biochemistry 110A', 'D-', 'NC']]]
#     [[['Biology 005A', 'D-', 'NC']], [['Biology 005B', 'D-', 'NC']], [['Biology 005C', 'D-', 'NC']], [['Biology 05LA', 'D-', 'NC'], ['Biology 020', 'D-', 'NC']], [['Chemistry 001C', 'D-', 'NC'], ['Chemistry 01HC', 'D-', 'NC']], [['Chemistry 008C', 'D-', 'NC']], [['Chemistry 08LC', 'D-', 'NC'], ['Chemistry 08HC', 'D-', 'NC']], [['Chemistry 08HLC', 'D-', 'NC'], ['Chemistry 12C', 'D-', 'NC'], ['Chemistry 12HC', 'D-', 'NC']], [['PHYS002C', 'D-', 'NC']], [['PHYS02LC', 'D-', 'NC']], [['Biochemistry 100', 'D-', 'NC'], ['Biochemistry 110A', 'D-', 'NC']], [['MATH007B', 'D-', 'NC'], ['MATH009B', 'D-', 'NC'], ['MATH09HB', 'D-', 'NC']]]
#     {}
#     [[['Biology 110C', 'D-', 'NC'], ['Biology 107A', 'D-', 'NC']], [['Biology 102', 'D-', 'NC']]]
#     {}
#     {}

# %%
### RENDER GRAPH {

def undergradOnly(courseList):
    numbers = set('0123456789')
    return [x for x in courseList if [y for y in x.courseName if y in numbers][0] in {'0','1'}]

def selectMajor(courseList,major):
    # Use 4-code for major (eg 'PHYS')
    return [x for x in courseList if x.subject == major]

len(courseList)
len(selectMajor(courseList,'PHYS'))

major = 'PHYS'
if remove_grad_classes:
    physList = undergradOnly(selectMajor(courseList,major))
else:
    physList = selectMajor(courseList,major)

dot = Digraph(comment='classflow test')


# Define how to draw between courses (with all the relevant conditions)
def requisiteLine(fromCourse,toCourse,graph,**args):
    """fromCourse example: "['ANTH001', 'D-', 'NC']"
       toCourse example: "course" object with courseName, etc.
       Creates nodes on both ends, then draws the requisite line between the two of them.
       Also references the global required list"""
    # Create nodes
    if color_requirements:
        for toNode in [fromCourse[0],toCourse.courseName]:
            if toNode in required:
                dot.node(toNode,style='filled',color='gold',shape='Msquare')
            else:
                dot.node(toNode,style='filled',color='royalblue',shape='Msquare')
    else:
        for toNode in [fromCourse[0],toCourse.courseName]:
            dot.node(toNode)
    
    # Draw line
    graph.edge(fromCourse[0],toCourse.courseName,**args)

# Create lines between courses
runID = 0
for i in physList:
    if i.preReq != dict():
        # i.preReq is "and_group"
        for orGroup in i.preReq:
            if len(orGroup) > 1:
                # draw box
                with dot.subgraph(name='cluster_' + str(runID)) as c:
                    for classInfo in orGroup:
                        if draw_boxes:
                            c.attr(style='filled')
                            c.attr(color='lightgrey')
                            c.node_attr.update(style='filled', color='white')
                            requisiteLine(classInfo,i,c,style='dashed')
                        else:
                            requisiteLine(classInfo,i,dot,style='dashed')
                runID += 1
            else:
                requisiteLine(orGroup[0],i,dot)

# if color_requirements:
#     # Color classes that are required
#     required = {'PHYS039','MATH009A','MATH009B','MATH009C','CHEM001A',
#                 'CHEM001B','CHEM001C','CS010','MATH010A','MATH010B','MATH046',
#                 'PHYS041A','PHYS041B','PHYS041C','PHYS130A','PHYS130B','PHYS132',
#                 'PHYS135A','PHYS135B','PHYS156A','PHYS156B','PHYS139L','PHYS142W'}
#     current_nodes = set([x.split(' ')[0][1:] for x in dot.__dict__['body']])
#     current_nodes.remove('subgraph')
#     current_nodes.remove('}')
#     for node in current_nodes:
#         if node in required:
#             dot.node(node, style='filled',color='gold')
#         else:
#             dot.node(node, style='filled',color='lightblue')

### }

# %%
dot.render(filename='./test',view=True,format='png')
# Out:
# './test.png'

# %%
dot
