# %%
from graphviz import Digraph

# %%
dot = Digraph(comment='The Round Table')

# %%
dot.node('A', 'King Arthur') # A is the bound name of the King Arthur node
dot.node('B', 'Sir Bedevere the Wise',xlabel='yes')
dot.node('L', 'Sir Lancelot the Brave',xlabel='yes')

dot.edges(['AB','AL'])
dot.edge('B','L',constraint='false')

# %%
print(dot)
# Out:
# // The Round Table
# digraph {
# 	A [label="King Arthur"]
# 	B [label="Sir Bedevere the Wise"]
# 	L [label="Sir Lancelot the Brave"]
# 	A -> B
# 	A -> L
# 	B -> L [constraint=false]
# }

# %%
dot.render('test-output/round-table.gv', view=True)
# Out:
# 'test-output/round-table.gv.pdf'

# %%
dot

# %%
dot.node('Larry the Dude')

# %%
dot.edge('B','Larry the Dude')
dot.edge('A','Larry the Dude')
dot.edge('L','Larry the Dude')

# %%
dot
